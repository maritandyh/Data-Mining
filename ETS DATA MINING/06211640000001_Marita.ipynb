# %% [markdown]
# # ETS DATA MINING
# ## Association Rule
# ### Online Retail Datase

# %%
import pandas as pd
import numpy as np
from apyori import apriori

# %%
data = pd.read_excel('E:\Kuliah\Semester 6\DATMIN\ETS\Online Retail.xlsx')

# %%
# menghilangkan data transaksi yang diawali dengan huruf C
# karena kode transaksi yang dimulai dengan huruf 'C' ini menunjukkan pembatalan
data['InvoiceNo'] = data['InvoiceNo'].astype('str')
data = data[~data['InvoiceNo'].str.contains('C')]

# %%
# menghilangkan data kuantitas yang bernilai -
# karena kuantitas yang bernilai - menunjukkan bahwa tidak terjadi transaksi (bisa pembatalan atau masalah lainnya)
data['Quantity'] = data['Quantity'].astype('str')
data = data[~data['Quantity'].str.contains('-')]

# %%
# menghilangkan data harga satuan yang bernilai 0
# karena apabila ada transaksi harga satuan tidak mungkin bernilai 0 (harga satuan 0 pada deskripsi barang yang dibeli berisi kosong atau terdapat masalah lainnya)
data['UnitPrice'] = data['UnitPrice'].astype('str')
data = data[~data['UnitPrice'].str.contains('0')]

# %%
# menghilangkan data harga satuan yang bernilai -
# karena apabila ada transaksi harga satuan tidak mungkin bernilai negatif
data['UnitPrice'] = data['UnitPrice'].astype('str')
data = data[~data['UnitPrice'].str.contains('-')]

# %%
np.sum(data.isnull())
# Out:
# InvoiceNo           0
# StockCode           0
# Description         0
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     107989
# Country             0
# dtype: int64

# %%
# membuat list deskripsi barang yang dibeli tiap kode transaksi (InvoiceNo)
x = data.groupby('InvoiceNo')
transaksi = []
for i, j  in x :
    transaksi.append(list(j['Description'].map(str)))

# %%
databaru = pd.DataFrame(transaksi)

# %%
databaru.shape
# Out:
# (19168, 923)

# %%
records=[]
for i in range (0,19168): 
    records.append([str(databaru.values[i,j]) for j in range (0, 923)])

# %%
# association rule
association_rules=apriori(records,min_support=0.0045, 
                          min_confidence=0.2, 
                          min_lift=2, min_length=2) 

association_result=list(association_rules)

# %%
association_result[0]
# Out:
# RelationRecord(items=frozenset({' DOLLY GIRL BEAKER', 'DOLLY GIRL LUNCH BOX'}), support=0.004747495826377296, ordered_statistics=[OrderedStatistic(items_base=frozenset({' DOLLY GIRL BEAKER'}), items_add=frozenset({'DOLLY GIRL LUNCH BOX'}), confidence=0.5384615384615385, lift=12.142624434389141)])

# %%
for item in association_result:
    #first index of the inner list
    #contains base item and add item
    pair = item[0]
    items=[x for x in pair]
    print("rule: " + items[0] + "->" + items[1])
    
    #second index of inner list
    print("support: " + str(item[1]))
    
    #third index of the list located at 10th
    #of the third index of the inner list
    
    print("confidence: " + str(item[2][0][2]))
    print("lift: " + str(item[2][0][3]))
    print("==========================================================================")
# Out:
# rule:  DOLLY GIRL BEAKER->DOLLY GIRL LUNCH BOX
# support: 0.004747495826377296
# confidence: 0.5384615384615385
# lift: 12.142624434389141
# ==========================================================================
# rule:  DOLLY GIRL BEAKER->SPACEBOY BEAKER
# support: 0.006260434056761269
# confidence: 0.7100591715976332
# lift: 76.03583352616442
# ==========================================================================
# rule:  SET 2 TEA TOWELS I LOVE LONDON ->LUNCH BOX I LOVE LONDON
# support: 0.005269198664440734
# confidence: 0.3754646840148699
# lift: 10.179500796601168
# ==========================================================================
# rule:  SPACEBOY BABY GIFT SET->DOLLY GIRL BABY GIFT SET
# support: 0.004695325542570952
# confidence: 0.5844155844155844
# lift: 91.07380424453594
# ==========================================================================
# rule: 3 DRAWER ANTIQUE WHITE WOOD CABINET->WOOD 2 DRAWER CABINET WHITE FINISH
# support: 0.005790901502504174
# confidence: 0.5495049504950495
# lift: 19.39762595044035
# ==========================================================================
# rule: 3 HEARTS HANGING DECORATION RUSTIC->PAPER CHAIN KIT 50'S CHRISTMAS
# support: 0.005164858096828047
# confidence: 0.32673267326732675
# lift: 5.39897575964493
# ==========================================================================
# rule: 3 HEARTS HANGING DECORATION RUSTIC->WHITE HANGING HEART T-LIGHT HOLDER
# support: 0.004851836393989983
# confidence: 0.3069306930693069
# lift: 2.607822484376097
# ==========================================================================
# rule: WHITE HANGING HEART T-LIGHT HOLDER->3 HOOK PHOTO SHELF ANTIQUE WHITE
# support: 0.005060517529215359
# confidence: 0.2539267015706806
# lift: 2.157476514054435
# ==========================================================================
# rule: 3 HOOK PHOTO SHELF ANTIQUE WHITE->WOODEN PICTURE FRAME WHITE FINISH
# support: 0.004643155258764607
# confidence: 0.23298429319371725
# lift: 4.108411160935761
# ==========================================================================
# rule: GINGERBREAD MAN COOKIE CUTTER->3 PIECE SPACEBOY COOKIE CUTTER SET
# support: 0.006416944908180301
# confidence: 0.3253968253968254
# lift: 9.55161768638032
# ==========================================================================
# rule: 3 PIECE SPACEBOY COOKIE CUTTER SET->JAM MAKING SET PRINTED
# support: 0.004799666110183639
# confidence: 0.24338624338624337
# lift: 4.01482574288082
# ==========================================================================
# rule: SET OF 20 KIDS COOKIE CUTTERS->3 PIECE SPACEBOY COOKIE CUTTER SET
# support: 0.005060517529215359
# confidence: 0.25661375661375657
# lift: 9.514066705556067
# ==========================================================================
# rule: SET OF 3 BUTTERFLY COOKIE CUTTERS->3 PIECE SPACEBOY COOKIE CUTTER SET
# support: 0.007408180300500835
# confidence: 0.37566137566137564
# lift: 10.558177783984236
# ==========================================================================
# rule: SET OF 3 HEART COOKIE CUTTERS->3 PIECE SPACEBOY COOKIE CUTTER SET
# support: 0.006469115191986645
# confidence: 0.328042328042328
# lift: 9.24693432928727
# ==========================================================================
# rule: 3 PIECE SPACEBOY COOKIE CUTTER SET->SET OF 4 PANTRY JELLY MOULDS
# support: 0.004747495826377296
# confidence: 0.24074074074074073
# lift: 4.50196928635953
# ==========================================================================
# rule: 3 PIECE SPACEBOY COOKIE CUTTER SET->SPACEBOY LUNCH BOX
# support: 0.004695325542570952
# confidence: 0.2380952380952381
# lift: 5.070899470899471
# ==========================================================================
# rule: FELTCRAFT 6 FLOWER FRIENDS->3 STRIPEY MICE FELTCRAFT
# support: 0.007199499165275459
# confidence: 0.2980561555075594
# lift: 10.52143718005322
# ==========================================================================
# rule: 3 STRIPEY MICE FELTCRAFT->FELTCRAFT BUTTERFLY HEARTS
# support: 0.007564691151919867
# confidence: 0.31317494600431967
# lift: 12.480119261976714
# ==========================================================================
# rule: FELTCRAFT PRINCESS CHARLOTTE DOLL->3 STRIPEY MICE FELTCRAFT
# support: 0.004956176961602671
# confidence: 0.20518358531317496
# lift: 8.759374083035496
# ==========================================================================
# rule: 3 STRIPEY MICE FELTCRAFT->JAM MAKING SET PRINTED
# support: 0.004851836393989983
# confidence: 0.20086393088552915
# lift: 3.3133905569826356
# ==========================================================================
# rule: 3 STRIPEY MICE FELTCRAFT->PAPER CHAIN KIT 50'S CHRISTMAS
# support: 0.004956176961602671
# confidence: 0.20518358531317496
# lift: 3.390481864899084
# ==========================================================================
# rule: 3 STRIPEY MICE FELTCRAFT->PINK BLUE FELT CRAFT TRINKET BOX
# support: 0.005373539232053423
# confidence: 0.2224622030237581
# lift: 8.52831101511879
# ==========================================================================
# rule: 3 STRIPEY MICE FELTCRAFT->PINK CREAM FELT CRAFT TRINKET BOX
# support: 0.006260434056761269
# confidence: 0.2591792656587473
# lift: 8.225079741965015
# ==========================================================================
# rule: 3 STRIPEY MICE FELTCRAFT->TRADITIONAL KNITTING NANCY
# support: 0.005060517529215359
# confidence: 0.20950323974082072
# lift: 6.594019867573156
# ==========================================================================
# rule: GINGERBREAD MAN COOKIE CUTTER->3 TRADITIONAl BISCUIT CUTTERS  SET
# support: 0.004799666110183639
# confidence: 0.396551724137931
# lift: 11.640280931509741
# ==========================================================================
# rule: SET OF 3 BUTTERFLY COOKIE CUTTERS->3 TRADITIONAl BISCUIT CUTTERS  SET
# support: 0.0049040066777963276
# confidence: 0.4051724137931035
# lift: 11.387602386490041
# ==========================================================================
# rule: SET OF 3 HEART COOKIE CUTTERS->3 TRADITIONAl BISCUIT CUTTERS  SET
# support: 0.005269198664440734
# confidence: 0.43534482758620685
# lift: 12.27160243407708
# ==========================================================================
# rule: 36 PENCILS TUBE RED RETROSPOT->36 PENCILS TUBE SKULLS
# support: 0.006521285475792988
# confidence: 0.39308176100628933
# lift: 28.86816549796381
# ==========================================================================
# rule: 36 PENCILS TUBE RED RETROSPOT->WHITE HANGING HEART T-LIGHT HOLDER
# support: 0.004747495826377296
# confidence: 0.2861635220125786
# lift: 2.4313751728444624
# ==========================================================================
# rule: 3D TRADITIONAL CHRISTMAS STICKERS->3D VINTAGE CHRISTMAS STICKERS
# support: 0.005217028380634391
# confidence: 0.5076142131979695
# lift: 52.03181411004642
# ==========================================================================
# rule: 3D TRADITIONAL CHRISTMAS STICKERS->PAPER CHAIN KIT 50'S CHRISTMAS
# support: 0.004747495826377296
# confidence: 0.4619289340101523
# lift: 7.632977419919482
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->4 TRADITIONAL SPINNING TOPS
# support: 0.005321368948247079
# confidence: 0.21338912133891214
# lift: 4.282976625993998
# ==========================================================================
# rule: BLUE HARMONICA IN BOX ->4 TRADITIONAL SPINNING TOPS
# support: 0.006156093489148581
# confidence: 0.24686192468619245
# lift: 7.899581589958158
# ==========================================================================
# rule: FLORAL FOLK STATIONERY SET->4 TRADITIONAL SPINNING TOPS
# support: 0.0049040066777963276
# confidence: 0.2211764705882353
# lift: 8.869269013044548
# ==========================================================================
# rule: GREEN REGENCY TEACUP AND SAUCER->4 TRADITIONAL SPINNING TOPS
# support: 0.005321368948247079
# confidence: 0.21338912133891214
# lift: 4.037751903084174
# ==========================================================================
# rule: 4 TRADITIONAL SPINNING TOPS->JAM MAKING SET PRINTED
# support: 0.005947412353923205
# confidence: 0.23849372384937237
# lift: 3.9341202226719187
# ==========================================================================
# rule: JAM MAKING SET WITH JARS->4 TRADITIONAL SPINNING TOPS
# support: 0.005895242070116861
# confidence: 0.23640167364016734
# lift: 4.002956961426438
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->4 TRADITIONAL SPINNING TOPS
# support: 0.005269198664440734
# confidence: 0.21129707112970708
# lift: 2.607947366010448
# ==========================================================================
# rule: 4 TRADITIONAL SPINNING TOPS->MODERN FLORAL STATIONERY SET
# support: 0.004956176961602671
# confidence: 0.25956284153005466
# lift: 10.408578549054576
# ==========================================================================
# rule: NATURAL SLATE HEART CHALKBOARD ->4 TRADITIONAL SPINNING TOPS
# support: 0.005947412353923205
# confidence: 0.23849372384937237
# lift: 3.660086227978198
# ==========================================================================
# rule: PAPER CHAIN KIT 50'S CHRISTMAS ->4 TRADITIONAL SPINNING TOPS
# support: 0.0059995826377295496
# confidence: 0.24058577405857742
# lift: 3.975472514788631
# ==========================================================================
# rule: PICTURE DOMINOES->4 TRADITIONAL SPINNING TOPS
# support: 0.004851836393989983
# confidence: 0.2612359550561798
# lift: 10.475671101499696
# ==========================================================================
# rule: RECIPE BOX PANTRY YELLOW DESIGN->4 TRADITIONAL SPINNING TOPS
# support: 0.005582220367278798
# confidence: 0.22384937238493724
# lift: 3.8620564985368833
# ==========================================================================
# rule: RED  HARMONICA IN BOX ->4 TRADITIONAL SPINNING TOPS
# support: 0.006521285475792988
# confidence: 0.2615062761506276
# lift: 7.9438229813870525
# ==========================================================================
# rule: RED TOADSTOOL LED NIGHT LIGHT->4 TRADITIONAL SPINNING TOPS
# support: 0.005634390651085142
# confidence: 0.22594142259414224
# lift: 5.101113295977053
# ==========================================================================
# rule: REGENCY CAKESTAND 3 TIER->4 TRADITIONAL SPINNING TOPS
# support: 0.006051752921535893
# confidence: 0.24267782426778242
# lift: 2.7737916133362277
# ==========================================================================
# rule: ROSES REGENCY TEACUP AND SAUCER ->4 TRADITIONAL SPINNING TOPS
# support: 0.005164858096828047
# confidence: 0.20711297071129706
# lift: 3.7276445282574104
# ==========================================================================
# rule: SET OF 6 SOLDIER SKITTLES->4 TRADITIONAL SPINNING TOPS
# support: 0.006312604340567613
# confidence: 0.2531380753138075
# lift: 10.952935953984339
# ==========================================================================
# rule: 4 TRADITIONAL SPINNING TOPS->SKULL SHOULDER BAG
# support: 0.004799666110183639
# confidence: 0.2238442822384428
# lift: 8.976249376457053
# ==========================================================================
# rule: SUKI  SHOULDER BAG->4 TRADITIONAL SPINNING TOPS
# support: 0.005373539232053423
# confidence: 0.21548117154811716
# lift: 7.793100181574169
# ==========================================================================
# rule: TRADITIONAL KNITTING NANCY->4 TRADITIONAL SPINNING TOPS
# support: 0.007147328881469115
# confidence: 0.28661087866108786
# lift: 9.020947983868197
# ==========================================================================
# rule: TRADITIONAL WOODEN CATCH CUP GAME ->4 TRADITIONAL SPINNING TOPS
# support: 0.009129799666110184
# confidence: 0.36610878661087864
# lift: 17.11603224818859
# ==========================================================================
# rule: TRADITIONAL WOODEN SKIPPING ROPE->4 TRADITIONAL SPINNING TOPS
# support: 0.00761686143572621
# confidence: 0.305439330543933
# lift: 13.97293815719835
# ==========================================================================
# rule: VICTORIAN GLASS HANGING T-LIGHT->4 TRADITIONAL SPINNING TOPS
# support: 0.005425709515859766
# confidence: 0.21757322175732216
# lift: 4.294998470282545
# ==========================================================================
# rule: VINTAGE HEADS AND TAILS CARD GAME ->4 TRADITIONAL SPINNING TOPS
# support: 0.007147328881469115
# confidence: 0.28661087866108786
# lift: 9.29569766865606
# ==========================================================================
# rule: VINTAGE SNAP CARDS->4 TRADITIONAL SPINNING TOPS
# support: 0.004695325542570952
# confidence: 0.43902439024390244
# lift: 17.60506174099398
# ==========================================================================
# rule: WHITE HANGING HEART T-LIGHT HOLDER->4 TRADITIONAL SPINNING TOPS
# support: 0.006312604340567613
# confidence: 0.2531380753138075
# lift: 2.150775987418024
# ==========================================================================
# rule: 4 TRADITIONAL SPINNING TOPS->WOODEN BOX OF DOMINOES
# support: 0.006834307178631051
# confidence: 0.2740585774058577
# lift: 8.995128102252535
# ==========================================================================
# rule: 6 RIBBONS ELEGANT CHRISTMAS ->PAPER CHAIN KIT 50'S CHRISTMAS
# support: 0.0049040066777963276
# confidence: 0.5340909090909092
# lift: 8.825391849529781
# ==========================================================================
# rule: 6 RIBBONS EMPIRE  ->6 RIBBONS RUSTIC CHARM
# support: 0.006364774624373956
# confidence: 0.5837320574162679
# lift: 11.716205315764421
# ==========================================================================
# rule: 6 RIBBONS EMPIRE  ->6 RIBBONS SHIMMERING PINKS
# support: 0.004695325542570952
# confidence: 0.430622009569378
# lift: 56.150766526706384
# ==========================================================================
# rule: 6 RIBBONS EMPIRE  ->JAM MAKING SET PRINTED
# support: 0.004695325542570952
# confidence: 0.430622009569378
# lift: 7.103410223258036
# ==========================================================================
# rule: 6 RIBBONS EMPIRE  ->REGENCY CAKESTAND 3 TIER
# support: 0.004643155258764607
# confidence: 0.4258373205741627
# lift: 4.867292642078444
# ==========================================================================
# rule: 6 RIBBONS EMPIRE  ->SKULL SHOULDER BAG
# support: 0.005269198664440734
# confidence: 0.4832535885167464
# lift: 22.53772453695619
# ==========================================================================
# rule: 6 RIBBONS EMPIRE  ->SUKI  SHOULDER BAG
# support: 0.004956176961602671
# confidence: 0.4545454545454546
# lift: 16.43910806174957
# ==========================================================================
# rule: 60 TEATIME FAIRY CAKE CASES->6 RIBBONS RUSTIC CHARM
# support: 0.004956176961602671
# confidence: 0.5654761904761905
# lift: 11.349788082772376
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->AIRLINE BAG VINTAGE TOKYO 78
# support: 0.004590984974958264
# confidence: 0.22448979591836732
# lift: 4.505780532108131
# ==========================================================================
# rule: BATHROOM METAL SIGN->6 RIBBONS RUSTIC CHARM
# support: 0.004956176961602671
# confidence: 0.37698412698412703
# lift: 7.566525388514918
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->BUTTON BOX
# support: 0.004590984974958264
# confidence: 0.352
# lift: 7.065063874345549
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->CHARLIE+LOLA PINK HOT WATER BOTTLE
# support: 0.006521285475792988
# confidence: 0.4152823920265781
# lift: 8.335217686246542
# ==========================================================================
# rule: CHARLOTTE BAG PINK POLKADOT->6 RIBBONS RUSTIC CHARM
# support: 0.005843071786310518
# confidence: 0.42105263157894735
# lift: 8.451033342518599
# ==========================================================================
# rule: CHARLOTTE BAG SUKI DESIGN->6 RIBBONS RUSTIC CHARM
# support: 0.006103923205342237
# confidence: 0.3979591836734694
# lift: 7.987520034191687
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->CHOCOLATE BOX RIBBONS
# support: 0.008347245409015025
# confidence: 0.5211726384364821
# lift: 10.460562443508366
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->CHRISTMAS CRAFT TREE TOP ANGEL
# support: 0.005425709515859766
# confidence: 0.2275711159737418
# lift: 4.567626336109615
# ==========================================================================
# rule: DELUXE SEWING KIT ->6 RIBBONS RUSTIC CHARM
# support: 0.005269198664440734
# confidence: 0.3079268292682926
# lift: 6.1804622653556365
# ==========================================================================
# rule: DOTCOM POSTAGE->6 RIBBONS RUSTIC CHARM
# support: 0.007042988313856427
# confidence: 0.26679841897233203
# lift: 5.35496554435776
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->FLORAL FOLK STATIONERY SET
# support: 0.006573455759599332
# confidence: 0.2964705882352941
# lift: 5.950521712349861
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->JAM MAKING SET PRINTED
# support: 0.012312186978297161
# confidence: 0.24712041884816752
# lift: 4.076423570121923
# ==========================================================================
# rule: JAM MAKING SET WITH JARS->6 RIBBONS RUSTIC CHARM
# support: 0.010799248747913189
# confidence: 0.21675392670157068
# lift: 3.670264370155218
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->JUMBO BAG APPLES
# support: 0.004851836393989983
# confidence: 0.2844036697247706
# lift: 5.708324126999375
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->JUMBO BAG OWLS
# support: 0.004956176961602671
# confidence: 0.22041763341067286
# lift: 4.424047326927515
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->JUMBO BAG PINK VINTAGE PAISLEY
# support: 0.006364774624373956
# confidence: 0.26991150442477874
# lift: 5.417448918130009
# ==========================================================================
# rule: JUMBO BAG WOODLAND ANIMALS->6 RIBBONS RUSTIC CHARM
# support: 0.005947412353923205
# confidence: 0.2222222222222222
# lift: 4.460267597440372
# ==========================================================================
# rule: JUMBO STORAGE BAG SKULLS->6 RIBBONS RUSTIC CHARM
# support: 0.005060517529215359
# confidence: 0.26358695652173914
# lift: 5.290507625768267
# ==========================================================================
# rule: KNITTED UNION FLAG HOT WATER BOTTLE->6 RIBBONS RUSTIC CHARM
# support: 0.004799666110183639
# confidence: 0.20043572984749453
# lift: 4.022986460436414
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->LARGE HEART MEASURING SPOONS
# support: 0.004956176961602671
# confidence: 0.2546916890080429
# lift: 5.111968895189703
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->LOVEBIRD HANGING DECORATION WHITE
# support: 0.005008347245409015
# confidence: 0.4067796610169492
# lift: 8.164557635992546
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->MODERN FLORAL STATIONERY SET
# support: 0.005686560934891486
# confidence: 0.2978142076502732
# lift: 5.977489771979515
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->NATURAL SLATE HEART CHALKBOARD
# support: 0.010329716193656094
# confidence: 0.20732984293193718
# lift: 3.1818242028177517
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->PACK OF 72 RETROSPOT CAKE CASES
# support: 0.005530050083472454
# confidence: 0.5047619047619047
# lift: 10.131179257043131
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->PANTRY MAGNETIC  SHOPPING LIST
# support: 0.005008347245409015
# confidence: 0.20253164556962028
# lift: 4.065054012857049
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->PAPER CHAIN KIT RETROSPOT
# support: 0.007303839732888147
# confidence: 0.2295081967213115
# lift: 4.606505879323664
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->PHOTO CUBE
# support: 0.005164858096828047
# confidence: 0.30841121495327106
# lift: 6.190184469344816
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->PICTURE DOMINOES
# support: 0.004695325542570952
# confidence: 0.252808988764045
# lift: 5.074180834166717
# ==========================================================================
# rule: PINK BLUE FELT CRAFT TRINKET BOX->6 RIBBONS RUSTIC CHARM
# support: 0.005217028380634391
# confidence: 0.2
# lift: 4.014240837696335
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->RECIPE BOX PANTRY YELLOW DESIGN
# support: 0.01095575959933222
# confidence: 0.21989528795811517
# lift: 3.7938369753205685
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->RED RETROSPOT CHARLOTTE BAG
# support: 0.00667779632721202
# confidence: 0.43686006825938567
# lift: 8.768307631828172
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->RED RETROSPOT OVEN GLOVE
# support: 0.004851836393989983
# confidence: 0.20945945945945943
# lift: 4.20410358001981
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->REGENCY CAKESTAND 3 TIER
# support: 0.01189482470784641
# confidence: 0.23874345549738218
# lift: 2.728822036358868
# ==========================================================================
# rule: RIBBON REEL CHRISTMAS SOCK BAUBLE->6 RIBBONS RUSTIC CHARM
# support: 0.00547787979966611
# confidence: 0.330188679245283
# lift: 6.627284401857156
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->RIBBON REEL HEARTS DESIGN
# support: 0.006469115191986645
# confidence: 0.3839009287925697
# lift: 7.70535392994343
# ==========================================================================
# rule: RIBBON REEL LACE DESIGN ->6 RIBBONS RUSTIC CHARM
# support: 0.00453881469115192
# confidence: 0.453125
# lift: 9.09476439790576
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->RIBBON REEL STRIPES DESIGN
# support: 0.007356010016694491
# confidence: 0.34474327628361856
# lift: 6.91941269089466
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->ROMANTIC PINKS RIBBONS
# support: 0.006103923205342237
# confidence: 0.5223214285714286
# lift: 10.48362004487659
# ==========================================================================
# rule: ROTATING LEAVES T-LIGHT HOLDER->6 RIBBONS RUSTIC CHARM
# support: 0.004956176961602671
# confidence: 0.31456953642384106
# lift: 6.313789397038938
# ==========================================================================
# rule: SCANDINAVIAN REDS RIBBONS->6 RIBBONS RUSTIC CHARM
# support: 0.011320951585976628
# confidence: 0.22722513089005233
# lift: 9.678780686445608
# ==========================================================================
# rule: SET OF 20 KIDS COOKIE CUTTERS->6 RIBBONS RUSTIC CHARM
# support: 0.005895242070116861
# confidence: 0.218568665377176
# lift: 4.386936311989225
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->SET OF 3 BUTTERFLY COOKIE CUTTERS
# support: 0.007408180300500835
# confidence: 0.20821114369501467
# lift: 4.179048379419938
# ==========================================================================
# rule: SET OF 3 NOTEBOOKS IN PARCEL->6 RIBBONS RUSTIC CHARM
# support: 0.004851836393989983
# confidence: 0.22037914691943128
# lift: 4.423274856703308
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->SET OF 6 RIBBONS VINTAGE CHRISTMAS
# support: 0.006729966611018364
# confidence: 0.30787589498806683
# lift: 6.179439953017031
# ==========================================================================
# rule: SET OF 72 PINK HEART PAPER DOILIES->6 RIBBONS RUSTIC CHARM
# support: 0.005634390651085142
# confidence: 0.21176470588235294
# lift: 4.250372651678473
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->SKULL SHOULDER BAG
# support: 0.007825542570951586
# confidence: 0.36496350364963503
# lift: 7.325257003095501
# ==========================================================================
# rule: SMALL GLASS HEART TRINKET POT->6 RIBBONS RUSTIC CHARM
# support: 0.006051752921535893
# confidence: 0.2144177449168207
# lift: 4.303622339859287
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->SMALL HEART MEASURING SPOONS
# support: 0.004799666110183639
# confidence: 0.4035087719298246
# lift: 8.098906953246992
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->STRAWBERRY CHARLOTTE BAG
# support: 0.005895242070116861
# confidence: 0.48497854077253216
# lift: 9.734103318877379
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->SUKI  SHOULDER BAG
# support: 0.007929883138564273
# confidence: 0.28679245283018867
# lift: 5.756269880470216
# ==========================================================================
# rule: TRADITIONAL CHRISTMAS RIBBONS->6 RIBBONS RUSTIC CHARM
# support: 0.007460350584307178
# confidence: 0.401685393258427
# lift: 8.06230954762045
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->TRADITIONAL KNITTING NANCY
# support: 0.006469115191986645
# confidence: 0.20361247947454847
# lift: 4.0867476508566964
# ==========================================================================
# rule: TRADITIONAL WOODEN CATCH CUP GAME ->6 RIBBONS RUSTIC CHARM
# support: 0.004851836393989983
# confidence: 0.2268292682926829
# lift: 4.5527365598263305
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->TRAVEL SEWING KIT
# support: 0.005582220367278798
# confidence: 0.2291220556745182
# lift: 4.598755563527921
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->VINTAGE PAISLEY STATIONERY SET
# support: 0.006416944908180301
# confidence: 0.2821100917431193
# lift: 5.662289255007446
# ==========================================================================
# rule: VINTAGE SNAKES & LADDERS->6 RIBBONS RUSTIC CHARM
# support: 0.005582220367278798
# confidence: 0.2702020202020202
# lift: 5.423279919614998
# ==========================================================================
# rule: VINTAGE SNAP CARDS->6 RIBBONS RUSTIC CHARM
# support: 0.005321368948247079
# confidence: 0.4975609756097561
# lift: 9.986647937683564
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->WHITE HANGING HEART T-LIGHT HOLDER
# support: 0.013407762938230384
# confidence: 0.26910994764397905
# lift: 2.28648026437934
# ==========================================================================
# rule: 6 RIBBONS RUSTIC CHARM->WICKER STAR
# support: 0.004799666110183639
# confidence: 0.22828784119106701
# lift: 4.582011874293584
# ==========================================================================
# rule: WOODLAND CHARLOTTE BAG->6 RIBBONS RUSTIC CHARM
# support: 0.00667779632721202
# confidence: 0.4266666666666667
# lift: 8.563713787085515
# ==========================================================================
# rule: 6 RIBBONS SHIMMERING PINKS ->SKULL SHOULDER BAG
# support: 0.004590984974958264
# confidence: 0.5986394557823129
# lift: 27.91902941225152
# ==========================================================================
# rule: 60 CAKE CASES VINTAGE CHRISTMAS->JAM MAKING SET PRINTED
# support: 0.004851836393989983
# confidence: 0.8157894736842105
# lift: 13.457016034061056
# ==========================================================================
# rule: PAPER CHAIN KIT 50'S CHRISTMAS ->60 CAKE CASES VINTAGE CHRISTMAS
# support: 0.004590984974958264
# confidence: 0.7719298245614036
# lift: 12.755474894131883
# ==========================================================================
# rule: 60 CAKE CASES VINTAGE CHRISTMAS->SKULL SHOULDER BAG
# support: 0.005008347245409015
# confidence: 0.8421052631578948
# lift: 39.273658599052375
# ==========================================================================
# rule: SUKI  SHOULDER BAG->60 CAKE CASES VINTAGE CHRISTMAS
# support: 0.004851836393989983
# confidence: 0.8157894736842105
# lift: 29.503872889771596
# ==========================================================================
# rule: CHARLOTTE BAG PINK POLKADOT->60 TEATIME FAIRY CAKE CASES
# support: 0.0049040066777963276
# confidence: 0.5595238095238095
# lift: 40.31936985320444
# ==========================================================================
# rule: CHARLOTTE BAG SUKI DESIGN->60 TEATIME FAIRY CAKE CASES
# support: 0.005530050083472454
# confidence: 0.6309523809523809
# lift: 41.13637836086816
# ==========================================================================
# rule: DOTCOM POSTAGE->60 TEATIME FAIRY CAKE CASES
# support: 0.005060517529215359
# confidence: 0.5773809523809523
# lift: 21.87201204592509
# ==========================================================================
# rule: 60 TEATIME FAIRY CAKE CASES->FLORAL FOLK STATIONERY SET
# support: 0.004747495826377296
# confidence: 0.5416666666666667
# lift: 24.429803921568627
# ==========================================================================
# rule: 60 TEATIME FAIRY CAKE CASES->GREEN REGENCY TEACUP AND SAUCER
# support: 0.004747495826377296
# confidence: 0.5416666666666667
# lift: 10.249424152681804
# ==========================================================================
# rule: 60 TEATIME FAIRY CAKE CASES->JAM MAKING SET PRINTED
# support: 0.004799666110183639
# confidence: 0.5476190476190477
# lift: 9.033357921481846
# ==========================================================================
# rule: 60 TEATIME FAIRY CAKE CASES->JUMBO BAG RED RETROSPOT
# support: 0.004590984974958264
# confidence: 0.5238095238095238
# lift: 9.921325051759835
# ==========================================================================
# rule: 60 TEATIME FAIRY CAKE CASES->MODERN FLORAL STATIONERY SET
# support: 0.004590984974958264
# confidence: 0.5238095238095238
# lift: 27.43273484257091
# ==========================================================================
# rule: 60 TEATIME FAIRY CAKE CASES->NATURAL SLATE HEART CHALKBOARD
# support: 0.004590984974958264
# confidence: 0.5238095238095238
# lift: 8.038735750505166
# ==========================================================================
# rule: 60 TEATIME FAIRY CAKE CASES->PACK OF 72 RETROSPOT CAKE CASES
# support: 0.005008347245409015
# confidence: 0.5714285714285714
# lift: 52.1578231292517
# ==========================================================================
# rule: 60 TEATIME FAIRY CAKE CASES->RECIPE BOX PANTRY YELLOW DESIGN
# support: 0.004643155258764607
# confidence: 0.5297619047619048
# lift: 9.139942565685141
# ==========================================================================
# rule: 60 TEATIME FAIRY CAKE CASES->RED RETROSPOT CHARLOTTE BAG
# support: 0.0059995826377295496
# confidence: 0.6845238095238095
# lift: 44.781407443523484
# ==========================================================================
# rule: 60 TEATIME FAIRY CAKE CASES->RED TOADSTOOL LED NIGHT LIGHT
# support: 0.005112687813021703
# confidence: 0.5833333333333334
# lift: 13.170003926187672
# ==========================================================================
# rule: 60 TEATIME FAIRY CAKE CASES->REGENCY CAKESTAND 3 TIER
# support: 0.005425709515859766
# confidence: 0.6190476190476191
# lift: 7.075673680324844
# ==========================================================================
# rule: 60 TEATIME FAIRY CAKE CASES->SKULL SHOULDER BAG
# support: 0.005321368948247079
# confidence: 0.6071428571428572
# lift: 28.31560653458464
# ==========================================================================
# rule: 60 TEATIME FAIRY CAKE CASES->STRAWBERRY CHARLOTTE BAG
# support: 0.004851836393989983
# confidence: 0.5535714285714286
# lift: 45.54015941140405
# ==========================================================================
# rule: 60 TEATIME FAIRY CAKE CASES->WHITE HANGING HEART T-LIGHT HOLDER
# support: 0.00453881469115192
# confidence: 0.5178571428571429
# lift: 4.399949341438703
# ==========================================================================
# rule: WOODLAND CHARLOTTE BAG->60 TEATIME FAIRY CAKE CASES
# support: 0.006312604340567613
# confidence: 0.7202380952380952
# lift: 46.018412698412696
# ==========================================================================
# rule: TREASURE ISLAND BOOK BOX->ABC TREASURE BOOK BOX
# support: 0.006573455759599332
# confidence: 0.5575221238938053
# lift: 40.02465944118524
# ==========================================================================
# rule: ADVENT CALENDAR GINGHAM SACK->PAPER CHAIN KIT 50'S CHRISTMAS
# support: 0.005634390651085142
# confidence: 0.43902439024390244
# lift: 7.254499579478553
# ==========================================================================
# rule: AIRLINE BAG VINTAGE JET SET BROWN->AIRLINE BAG VINTAGE TOKYO 78
# support: 0.005112687813021703
# confidence: 0.5868263473053893
# lift: 28.694610778443113
# ==========================================================================
# rule: AIRLINE BAG VINTAGE TOKYO 78->AIRLINE BAG VINTAGE JET SET RED
# support: 0.007303839732888147
# confidence: 0.6278026905829597
# lift: 30.698270339525944
# ==========================================================================
# rule: AIRLINE BAG VINTAGE TOKYO 78->AIRLINE BAG VINTAGE WORLD CHAMPION
# support: 0.005008347245409015
# confidence: 0.24489795918367344
# lift: 31.933361099541855
# ==========================================================================
# rule: ALARM CLOCK BAKELIKE GREEN->AIRLINE BAG VINTAGE TOKYO 78
# support: 0.0049040066777963276
# confidence: 0.23979591836734693
# lift: 4.69021241149521
# ==========================================================================
# rule: CHARLIE+LOLA PINK HOT WATER BOTTLE->AIRLINE BAG VINTAGE TOKYO 78
# support: 0.005217028380634391
# confidence: 0.25510204081632654
# lift: 16.24516916401112
# ==========================================================================
# rule: DOLLY GIRL LUNCH BOX->AIRLINE BAG VINTAGE TOKYO 78
# support: 0.005634390651085142
# confidence: 0.2755102040816326
# lift: 6.212917166866745
# ==========================================================================
# rule: DOTCOM POSTAGE->AIRLINE BAG VINTAGE TOKYO 78
# support: 0.005008347245409015
# confidence: 0.24489795918367344
# lift: 9.277083165281923
# ==========================================================================
# rule: FLORAL FOLK STATIONERY SET->AIRLINE BAG VINTAGE TOKYO 78
# support: 0.004956176961602671
# confidence: 0.2423469387755102
# lift: 10.930132052821127
# ==========================================================================
# rule: GARDENERS KNEELING PAD CUP OF TEA ->AIRLINE BAG VINTAGE TOKYO 78
# support: 0.004851836393989983
# confidence: 0.23724489795918363
# lift: 5.999353831242258
# ==========================================================================
# rule: GARDENERS KNEELING PAD KEEP CALM ->AIRLINE BAG VINTAGE TOKYO 78
# support: 0.005269198664440734
# confidence: 0.2576530612244898
# lift: 5.4093032612826075
# ==========================================================================
# rule: GREEN REGENCY TEACUP AND SAUCER->AIRLINE BAG VINTAGE TOKYO 78
# support: 0.005790901502504174
# confidence: 0.28316326530612246
# lift: 5.358019219533816
# ==========================================================================
# rule: HEART OF WICKER SMALL->AIRLINE BAG VINTAGE TOKYO 78
# support: 0.004956176961602671
# confidence: 0.2423469387755102
# lift: 3.867865214362181
# ==========================================================================
# rule: AIRLINE BAG VINTAGE TOKYO 78->JAM MAKING SET PRINTED
# support: 0.005895242070116861
# confidence: 0.28826530612244894
# lift: 4.755137166742772
# ==========================================================================
# rule: JAM MAKING SET WITH JARS->AIRLINE BAG VINTAGE TOKYO 78
# support: 0.005164858096828047
# confidence: 0.25255102040816324
# lift: 4.276411624720559
# ==========================================================================
# rule: JUMBO BAG RED RETROSPOT->AIRLINE BAG VINTAGE TOKYO 78
# support: 0.006573455759599332
# confidence: 0.3214285714285714
# lift: 6.088085827216262
# ==========================================================================
# rule: JUMBO SHOPPER VINTAGE RED PAISLEY->AIRLINE BAG VINTAGE TOKYO 78
# support: 0.004799666110183639
# confidence: 0.2346938775510204
# lift: 7.3386822918400645
# ==========================================================================
# rule: LUNCH BAG  BLACK SKULL.->AIRLINE BAG VINTAGE TOKYO 78
# support: 0.004799666110183639
# confidence: 0.2346938775510204
# lift: 3.550601613968397
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->AIRLINE BAG VINTAGE TOKYO 78
# support: 0.005321368948247079
# confidence: 0.2602040816326531
# lift: 3.211585213608947
# ==========================================================================
# rule: LUNCH BOX I LOVE LONDON->AIRLINE BAG VINTAGE TOKYO 78
# support: 0.005008347245409015
# confidence: 0.24489795918367344
# lift: 6.639609733568109
# ==========================================================================
# rule: NATURAL SLATE HEART CHALKBOARD ->AIRLINE BAG VINTAGE TOKYO 78
# support: 0.005164858096828047
# confidence: 0.25255102040816324
# lift: 3.8758190225649902
# ==========================================================================
# rule: PAPER CHAIN KIT 50'S CHRISTMAS ->AIRLINE BAG VINTAGE TOKYO 78
# support: 0.0049040066777963276
# confidence: 0.23979591836734693
# lift: 3.962420830401126
# ==========================================================================
# rule: RECIPE BOX PANTRY YELLOW DESIGN->AIRLINE BAG VINTAGE TOKYO 78
# support: 0.005790901502504174
# confidence: 0.28316326530612246
# lift: 4.885394661915171
# ==========================================================================
# rule: RECYCLING BAG RETROSPOT ->AIRLINE BAG VINTAGE TOKYO 78
# support: 0.005790901502504174
# confidence: 0.28316326530612246
# lift: 7.3149238131910455
# ==========================================================================
# rule: RED TOADSTOOL LED NIGHT LIGHT->AIRLINE BAG VINTAGE TOKYO 78
# support: 0.005843071786310518
# confidence: 0.2857142857142857
# lift: 6.450614167928655
# ==========================================================================
# rule: REGENCY CAKESTAND 3 TIER->AIRLINE BAG VINTAGE TOKYO 78
# support: 0.0049040066777963276
# confidence: 0.23979591836734693
# lift: 2.74085161792803
# ==========================================================================
# rule: ROSES REGENCY TEACUP AND SAUCER ->AIRLINE BAG VINTAGE TOKYO 78
# support: 0.005321368948247079
# confidence: 0.2602040816326531
# lift: 4.683184823225065
# ==========================================================================
# rule: ROTATING LEAVES T-LIGHT HOLDER->AIRLINE BAG VINTAGE TOKYO 78
# support: 0.00453881469115192
# confidence: 0.22193877551020408
# lift: 14.086498175429112
# ==========================================================================
# rule: AIRLINE BAG VINTAGE TOKYO 78->SKULL SHOULDER BAG
# support: 0.0059995826377295496
# confidence: 0.29336734693877553
# lift: 13.681910720492576
# ==========================================================================
# rule: SPACEBOY LUNCH BOX ->AIRLINE BAG VINTAGE TOKYO 78
# support: 0.005008347245409015
# confidence: 0.24489795918367344
# lift: 5.215782312925169
# ==========================================================================
# rule: SUKI  SHOULDER BAG->AIRLINE BAG VINTAGE TOKYO 78
# support: 0.007564691151919867
# confidence: 0.36989795918367346
# lift: 13.377743550250289
# ==========================================================================
# rule: WHITE HANGING HEART T-LIGHT HOLDER->AIRLINE BAG VINTAGE TOKYO 78
# support: 0.006521285475792988
# confidence: 0.31887755102040816
# lift: 2.70932841221595
# ==========================================================================
# rule: CHOCOLATE THIS WAY METAL SIGN->AIRLINE LOUNGE,METAL SIGN
# support: 0.004851836393989983
# confidence: 0.31958762886597936
# lift: 13.089435192527976
# ==========================================================================
# rule: DOTCOM POSTAGE->AIRLINE LOUNGE,METAL SIGN
# support: 0.005686560934891486
# confidence: 0.3745704467353952
# lift: 14.18926150795268
# ==========================================================================
# rule: AIRLINE LOUNGE,METAL SIGN->FLORAL FOLK STATIONERY SET
# support: 0.00547787979966611
# confidence: 0.36082474226804123
# lift: 16.273620375985445
# ==========================================================================
# rule: AIRLINE LOUNGE,METAL SIGN->GIN + TONIC DIET METAL SIGN
# support: 0.004643155258764607
# confidence: 0.3058419243986254
# lift: 8.019668956050413
# ==========================================================================
# rule: AIRLINE LOUNGE,METAL SIGN->GREEN REGENCY TEACUP AND SAUCER
# support: 0.005634390651085142
# confidence: 0.3711340206185567
# lift: 7.022603067341062
# ==========================================================================
# rule: AIRLINE LOUNGE,METAL SIGN->HAND OVER THE CHOCOLATE   SIGN
# support: 0.00453881469115192
# confidence: 0.29896907216494845
# lift: 8.477276886475936
# ==========================================================================
# rule: AIRLINE LOUNGE,METAL SIGN->JAM MAKING SET PRINTED
# support: 0.005738731218697829
# confidence: 0.37800687285223367
# lift: 6.2354868664643845
# ==========================================================================
# rule: JAM MAKING SET WITH JARS->AIRLINE LOUNGE,METAL SIGN
# support: 0.005217028380634391
# confidence: 0.3436426116838488
# lift: 5.818852986533581
# ==========================================================================
# rule: AIRLINE LOUNGE,METAL SIGN->JUMBO BAG RED RETROSPOT
# support: 0.005269198664440734
# confidence: 0.3470790378006873
# lift: 6.5739239096478
# ==========================================================================
# rule: AIRLINE LOUNGE,METAL SIGN->LUNCH BAG RED RETROSPOT
# support: 0.004695325542570952
# confidence: 0.30927835051546393
# lift: 3.8172874582616956
# ==========================================================================
# rule: AIRLINE LOUNGE,METAL SIGN->MODERN FLORAL STATIONERY SET
# support: 0.004851836393989983
# confidence: 0.31958762886597936
# lift: 16.737310574052163
# ==========================================================================
# rule: AIRLINE LOUNGE,METAL SIGN->NATURAL SLATE HEART CHALKBOARD
# support: 0.005373539232053423
# confidence: 0.3539518900343643
# lift: 5.431985450903678
# ==========================================================================
# rule: AIRLINE LOUNGE,METAL SIGN->RECIPE BOX PANTRY YELLOW DESIGN
# support: 0.005112687813021703
# confidence: 0.33676975945017185
# lift: 5.810263500576863
# ==========================================================================
# rule: AIRLINE LOUNGE,METAL SIGN->RED TOADSTOOL LED NIGHT LIGHT
# support: 0.004851836393989983
# confidence: 0.31958762886597936
# lift: 7.215377703301639
# ==========================================================================
# rule: AIRLINE LOUNGE,METAL SIGN->REGENCY CAKESTAND 3 TIER
# support: 0.004799666110183639
# confidence: 0.3161512027491409
# lift: 3.613587510015225
# ==========================================================================
# rule: ROSES REGENCY TEACUP AND SAUCER ->AIRLINE LOUNGE,METAL SIGN
# support: 0.004747495826377296
# confidence: 0.3127147766323024
# lift: 5.628278721584951
# ==========================================================================
# rule: AIRLINE LOUNGE,METAL SIGN->SET OF 4 PANTRY JELLY MOULDS
# support: 0.005217028380634391
# confidence: 0.3436426116838488
# lift: 6.426284469030257
# ==========================================================================
# rule: SMALL GLASS HEART TRINKET POT->AIRLINE LOUNGE,METAL SIGN
# support: 0.00453881469115192
# confidence: 0.29896907216494845
# lift: 10.592678697334069
# ==========================================================================
# rule: AIRLINE LOUNGE,METAL SIGN->SUKI  SHOULDER BAG
# support: 0.005112687813021703
# confidence: 0.33676975945017185
# lift: 12.179627828567725
# ==========================================================================
# rule: VICTORIAN GLASS HANGING T-LIGHT->AIRLINE LOUNGE,METAL SIGN
# support: 0.005373539232053423
# confidence: 0.3539518900343643
# lift: 6.98717798988537
# ==========================================================================
# rule: AIRLINE LOUNGE,METAL SIGN->VINTAGE PAISLEY STATIONERY SET
# support: 0.005164858096828047
# confidence: 0.3402061855670103
# lift: 14.956587534285445
# ==========================================================================
# rule: VINTAGE SNAP CARDS->AIRLINE LOUNGE,METAL SIGN
# support: 0.004590984974958264
# confidence: 0.3024054982817869
# lift: 28.27565166373313
# ==========================================================================
# rule: AIRLINE LOUNGE,METAL SIGN->WHITE HANGING HEART T-LIGHT HOLDER
# support: 0.006521285475792988
# confidence: 0.42955326460481097
# lift: 3.6496795106139257
# ==========================================================================
# rule: ALARM CLOCK BAKELIKE GREEN->ALARM CLOCK BAKELIKE CHOCOLATE
# support: 0.014451168614357262
# confidence: 0.647196261682243
# lift: 12.658630555025749
# ==========================================================================
# rule: ALARM CLOCK BAKELIKE IVORY->ALARM CLOCK BAKELIKE CHOCOLATE
# support: 0.009860183639398999
# confidence: 0.441588785046729
# lift: 14.928348909657322
# ==========================================================================
# rule: ALARM CLOCK BAKELIKE ORANGE->ALARM CLOCK BAKELIKE CHOCOLATE
# support: 0.008086393989983306
# confidence: 0.3621495327102804
# lift: 15.59928593930484
# ==========================================================================
# rule: ALARM CLOCK BAKELIKE PINK->ALARM CLOCK BAKELIKE CHOCOLATE
# support: 0.011477462437395659
# confidence: 0.514018691588785
# lift: 12.631679846633117
# ==========================================================================
# rule: ALARM CLOCK BAKELIKE RED ->ALARM CLOCK BAKELIKE CHOCOLATE
# support: 0.01523372287145242
# confidence: 0.6822429906542056
# lift: 12.44265808264492
# ==========================================================================
# rule: CHARLOTTE BAG SUKI DESIGN->ALARM CLOCK BAKELIKE CHOCOLATE
# support: 0.00453881469115192
# confidence: 0.20327102803738317
# lift: 13.252717909593745
# ==========================================================================
# rule: LUNCH BAG  BLACK SKULL.->ALARM CLOCK BAKELIKE CHOCOLATE
# support: 0.004799666110183639
# confidence: 0.21495327102803738
# lift: 3.2519528800832047
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->ALARM CLOCK BAKELIKE CHOCOLATE
# support: 0.004747495826377296
# confidence: 0.21261682242990654
# lift: 2.6242364792894066
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->ALARM CLOCK BAKELIKE CHOCOLATE
# support: 0.00453881469115192
# confidence: 0.20327102803738317
# lift: 3.3675877834231294
# ==========================================================================
# rule: PAPER CHAIN KIT 50'S CHRISTMAS ->ALARM CLOCK BAKELIKE CHOCOLATE
# support: 0.004695325542570952
# confidence: 0.2102803738317757
# lift: 3.4747019013857554
# ==========================================================================
# rule: RED RETROSPOT CHARLOTTE BAG->ALARM CLOCK BAKELIKE CHOCOLATE
# support: 0.00453881469115192
# confidence: 0.20327102803738317
# lift: 13.297949028739115
# ==========================================================================
# rule: REGENCY CAKESTAND 3 TIER->ALARM CLOCK BAKELIKE CHOCOLATE
# support: 0.0070951585976627716
# confidence: 0.3177570093457944
# lift: 3.6319417740847864
# ...
# support: 0.004851836393989983
# confidence: 0.7622950819672131
# lift: 14.481340070512925
# ==========================================================================
# rule: LUNCH BAG SUKI DESIGN ->LUNCH BAG APPLE DESIGN
# support: 0.005112687813021703
# confidence: 0.7205882352941176
# lift: 13.689033988223635
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG SUKI DESIGN
# support: 0.006364774624373956
# confidence: 0.8133333333333334
# lift: 14.38189421894219
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG APPLE DESIGN
# support: 0.005582220367278798
# confidence: 0.7133333333333334
# lift: 13.55121242153948
# ==========================================================================
# rule: LUNCH BAG SUKI DESIGN ->LUNCH BAG APPLE DESIGN
# support: 0.004851836393989983
# confidence: 0.5344827586206896
# lift: 15.33677472640925
# ==========================================================================
# rule: LUNCH BAG SUKI DESIGN ->LUNCH BAG APPLE DESIGN
# support: 0.005947412353923205
# confidence: 0.6551724137931034
# lift: 12.446327876695943
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG SUKI DESIGN
# support: 0.0049040066777963276
# confidence: 0.5949367088607596
# lift: 17.071477298567423
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG SUKI DESIGN
# support: 0.005582220367278798
# confidence: 0.6772151898734178
# lift: 12.865075083740013
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG SUKI DESIGN
# support: 0.004747495826377296
# confidence: 0.7913043478260869
# lift: 13.992363227980105
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG APPLE DESIGN
# support: 0.00453881469115192
# confidence: 0.7565217391304347
# lift: 14.371663722152798
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG SUKI DESIGN
# support: 0.005582220367278798
# confidence: 0.7430555555555556
# lift: 13.13919639196392
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG APPLE DESIGN
# support: 0.005530050083472454
# confidence: 0.736111111111111
# lift: 13.983922475498293
# ==========================================================================
# rule: LUNCH BAG SUKI DESIGN ->LUNCH BAG APPLE DESIGN
# support: 0.004851836393989983
# confidence: 0.5740740740740741
# lift: 16.472832113550677
# ==========================================================================
# rule: LUNCH BAG SUKI DESIGN ->LUNCH BAG APPLE DESIGN
# support: 0.005843071786310518
# confidence: 0.6913580246913581
# lift: 13.13374689522691
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG SUKI DESIGN
# support: 0.0049040066777963276
# confidence: 0.7580645161290323
# lift: 14.400971898078584
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG SUKI DESIGN
# support: 0.005582220367278798
# confidence: 0.6184971098265896
# lift: 17.747533834065973
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG SUKI DESIGN
# support: 0.0059995826377295496
# confidence: 0.6647398843930636
# lift: 12.628081371700937
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG APPLE DESIGN
# support: 0.004590984974958264
# confidence: 0.676923076923077
# lift: 12.859525806205689
# ==========================================================================
# rule: LUNCH BAG SUKI DESIGN ->LUNCH BAG APPLE DESIGN
# support: 0.004851836393989983
# confidence: 0.6549295774647887
# lift: 12.44171470846885
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG SUKI DESIGN
# support: 0.0049040066777963276
# confidence: 0.6714285714285715
# lift: 12.755146538298176
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG RED RETROSPOT
# support: 0.005008347245409015
# confidence: 0.8067226890756302
# lift: 13.364961542093067
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG SUKI DESIGN
# support: 0.004747495826377296
# confidence: 0.6740740740740742
# lift: 11.919420527538609
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG WOODLAND
# support: 0.005060517529215359
# confidence: 0.7185185185185186
# lift: 13.64971552325368
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG SUKI DESIGN
# support: 0.006416944908180301
# confidence: 0.640625
# lift: 11.327952029520295
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG WOODLAND
# support: 0.007199499165275459
# confidence: 0.71875
# lift: 13.654112983151636
# ==========================================================================
# rule: LUNCH BAG SUKI DESIGN ->LUNCH BAG RED RETROSPOT
# support: 0.004590984974958264
# confidence: 0.4680851063829787
# lift: 13.431519938845712
# ==========================================================================
# rule: LUNCH BAG SUKI DESIGN ->LUNCH BAG WOODLAND
# support: 0.006729966611018364
# confidence: 0.6861702127659574
# lift: 13.035193893258544
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG SUKI DESIGN
# support: 0.005634390651085142
# confidence: 0.7297297297297297
# lift: 13.862695202635738
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG SUKI DESIGN
# support: 0.004799666110183639
# confidence: 0.5
# lift: 14.347305389221557
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG SUKI DESIGN
# support: 0.006469115191986645
# confidence: 0.6739130434782609
# lift: 12.802344120308527
# ==========================================================================
# rule: LUNCH BAG SUKI DESIGN ->LUNCH BAG WOODLAND
# support: 0.00453881469115192
# confidence: 0.7372881355932204
# lift: 14.006282441081119
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG SUKI DESIGN
# support: 0.004695325542570952
# confidence: 0.7377049180327869
# lift: 14.014200068238315
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG SUKI DESIGN
# support: 0.004956176961602671
# confidence: 0.6643356643356644
# lift: 11.7472195700978
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG WOODLAND
# support: 0.005373539232053423
# confidence: 0.7202797202797203
# lift: 13.683173120239523
# ==========================================================================
# rule: LUNCH BAG SUKI DESIGN ->LUNCH BAG WOODLAND
# support: 0.004643155258764607
# confidence: 0.700787401574803
# lift: 13.312877020203988
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG SUKI DESIGN
# support: 0.005060517529215359
# confidence: 0.7080291970802919
# lift: 13.450449603206179
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG SUKI DESIGN
# support: 0.006208263772954925
# confidence: 0.734567901234568
# lift: 13.954606076178594
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG SUKI DESIGN
# support: 0.005164858096828047
# confidence: 0.7279411764705882
# lift: 13.82871800851163
# ==========================================================================
# rule: REGENCY SUGAR BOWL GREEN->ROSES REGENCY TEACUP AND SAUCER
# support: 0.004590984974958264
# confidence: 0.9361702127659574
# lift: 16.849305763659974
# ==========================================================================
# rule: REGENCY SUGAR BOWL GREEN->ROSES REGENCY TEACUP AND SAUCER
# support: 0.004590984974958264
# confidence: 0.9670329670329669
# lift: 17.40477738224217
# ==========================================================================
# rule: ROSES REGENCY TEACUP AND SAUCER ->PINK REGENCY TEACUP AND SAUCER
# support: 0.007356010016694491
# confidence: 0.9337748344370861
# lift: 16.806193452103347
# ==========================================================================
# rule: REGENCY SUGAR BOWL GREEN->REGENCY MILK JUG PINK
# support: 0.005530050083472454
# confidence: 0.9464285714285714
# lift: 40.76661316211878
# ==========================================================================
# rule: REGENCY SUGAR BOWL GREEN->REGENCY MILK JUG PINK
# support: 0.004956176961602671
# confidence: 0.8482142857142857
# lift: 39.177280550774526
# ==========================================================================
# rule: REGENCY SUGAR BOWL GREEN->REGENCY MILK JUG PINK
# support: 0.00547787979966611
# confidence: 0.875
# lift: 40.4144578313253
# ==========================================================================
# rule: REGENCY SUGAR BOWL GREEN->REGENCY MILK JUG PINK
# support: 0.004799666110183639
# confidence: 0.8518518518518519
# lift: 39.34529228023204
# ==========================================================================
# rule: REGENCY SUGAR BOWL GREEN->ROSES REGENCY TEACUP AND SAUCER
# support: 0.00453881469115192
# confidence: 0.6744186046511628
# lift: 12.138268369909378
# ==========================================================================
# rule: REGENCY MILK JUG PINK ->REGENCY TEA PLATE GREEN
# support: 0.0049040066777963276
# confidence: 0.8173913043478261
# lift: 37.75363017286538
# ==========================================================================
# rule: REGENCY SUGAR BOWL GREEN->REGENCY TEA PLATE GREEN
# support: 0.005634390651085142
# confidence: 0.8244274809160306
# lift: 38.078616757104754
# ==========================================================================
# rule: REGENCY SUGAR BOWL GREEN->ROSES REGENCY TEACUP AND SAUCER
# support: 0.005060517529215359
# confidence: 0.7404580152671756
# lift: 13.32685374332509
# ==========================================================================
# rule: REGENCY SUGAR BOWL GREEN->ROSES REGENCY TEACUP AND SAUCER
# support: 0.00453881469115192
# confidence: 0.7699115044247788
# lift: 13.85696123644522
# ==========================================================================
# rule: REGENCY SUGAR BOWL GREEN->ROSES REGENCY TEACUP AND SAUCER
# support: 0.005008347245409015
# confidence: 0.768
# lift: 13.822557746478873
# ==========================================================================
# rule: ROSES REGENCY TEACUP AND SAUCER ->REGENCY TEA PLATE GREEN
# support: 0.004747495826377296
# confidence: 0.7777777777777778
# lift: 13.998539384454878
# ==========================================================================
# rule: CHARLOTTE BAG SUKI DESIGN->RED RETROSPOT CHARLOTTE BAG
# support: 0.004799666110183639
# confidence: 0.9484536082474228
# lift: 60.59986254295533
# ==========================================================================
# rule: CHARLOTTE BAG SUKI DESIGN->RED RETROSPOT CHARLOTTE BAG
# support: 0.004590984974958264
# confidence: 0.9887640449438203
# lift: 63.175430711610495
# ==========================================================================
# rule: CHARLOTTE BAG SUKI DESIGN->RED RETROSPOT CHARLOTTE BAG
# support: 0.005530050083472454
# confidence: 0.9380530973451326
# lift: 59.93533923303834
# ==========================================================================
# rule: ROSES REGENCY TEACUP AND SAUCER ->PINK REGENCY TEACUP AND SAUCER
# support: 0.007042988313856427
# confidence: 0.9574468085106382
# lift: 17.23224453101588
# ==========================================================================
# rule: JUMBO SHOPPER VINTAGE RED PAISLEY->JUMBO BAG RED RETROSPOT
# support: 0.005634390651085142
# confidence: 0.9230769230769231
# lift: 27.951877506379876
# ==========================================================================
# rule: LUNCH BAG SUKI DESIGN ->LUNCH BAG APPLE DESIGN
# support: 0.004799666110183639
# confidence: 0.8141592920353983
# lift: 14.39649936322372
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG SUKI DESIGN
# support: 0.0049040066777963276
# confidence: 0.8468468468468469
# lift: 14.974502177454207
# ==========================================================================
# rule: LUNCH BAG SUKI DESIGN ->LUNCH BAG APPLE DESIGN
# support: 0.004851836393989983
# confidence: 0.7153846153846154
# lift: 13.590180681558284
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG SUKI DESIGN
# support: 0.00453881469115192
# confidence: 0.725
# lift: 13.772844400396432
# ==========================================================================
# rule: LUNCH BAG SUKI DESIGN ->LUNCH BAG APPLE DESIGN
# support: 0.004695325542570952
# confidence: 0.75
# lift: 14.24777006937562
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG SUKI DESIGN
# support: 0.004695325542570952
# confidence: 0.6923076923076924
# lift: 19.86549976969139
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG SUKI DESIGN
# support: 0.0049040066777963276
# confidence: 0.7230769230769232
# lift: 13.736311656628805
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG SUKI DESIGN
# support: 0.005321368948247079
# confidence: 0.723404255319149
# lift: 12.791709193687682
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG WOODLAND
# support: 0.00547787979966611
# confidence: 0.7446808510638298
# lift: 14.146722054699197
# ==========================================================================
# rule: LUNCH BAG SUKI DESIGN ->LUNCH BAG WOODLAND
# support: 0.005373539232053423
# confidence: 0.6821192052980133
# lift: 12.958236795988423
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG SUKI DESIGN
# support: 0.004799666110183639
# confidence: 0.7666666666666666
# lift: 14.56438718202841
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG SUKI DESIGN
# support: 0.005164858096828047
# confidence: 0.7279411764705882
# lift: 13.82871800851163
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG SUKI DESIGN
# support: 0.005112687813021703
# confidence: 0.7596899224806202
# lift: 14.43184978603422
# ==========================================================================
# rule: LUNCH BAG SUKI DESIGN ->LUNCH BAG APPLE DESIGN
# support: 0.004643155258764607
# confidence: 0.7807017543859649
# lift: 14.831012118999183
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG SUKI DESIGN
# support: 0.004590984974958264
# confidence: 0.7213114754098361
# lift: 13.702773400055241
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG SUKI DESIGN
# support: 0.005112687813021703
# confidence: 0.7967479674796748
# lift: 15.135842458523694
# ==========================================================================
# rule: REGENCY SUGAR BOWL GREEN->REGENCY MILK JUG PINK
# support: 0.004747495826377296
# confidence: 0.8584905660377359
# lift: 39.651920891111615
# ==========================================================================
