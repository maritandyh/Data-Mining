# %% [markdown]
# # ETS DATA MINING
# ## Association Rule
# ### Online Retail Dataset

# %%
import pandas as pd
import numpy as np
from apyori import apriori

# %%
data = pd.read_excel('E:\Kuliah\Semester 6\DATMIN\ETS\Online Retail.xlsx')

# %%
# menghilangkan data transaksi yang diawali dengan huruf C
# karena kode transaksi yang dimulai dengan huruf 'C' ini menunjukkan pembatalan
data['InvoiceNo'] = data['InvoiceNo'].astype('str')
data = data[~data['InvoiceNo'].str.contains('C')]

# %%
# menghilangkan data kuantitas yang bernilai -
# karena kuantitas yang bernilai - menunjukkan bahwa tidak terjadi transaksi (bisa pembatalan atau masalah lainnya)
data['Quantity'] = data['Quantity'].astype('str')
data = data[~data['Quantity'].str.contains('-')]

# %%
# menghilangkan data harga satuan yang bernilai 0
# karena apabila ada transaksi harga satuan tidak mungkin bernilai 0 (harga satuan 0 pada deskripsi barang yang dibeli berisi kosong atau terdapat masalah lainnya)
data['UnitPrice'] = data['UnitPrice'].astype('str')
data = data[~data['UnitPrice'].str.contains('0')]

# %%
# menghilangkan data harga satuan yang bernilai -
# karena apabila ada transaksi harga satuan tidak mungkin bernilai negatif
data['UnitPrice'] = data['UnitPrice'].astype('str')
data = data[~data['UnitPrice'].str.contains('-')]

# %%
np.sum(data.isnull())
# Out:
# InvoiceNo           0
# StockCode           0
# Description         0
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     107989
# Country             0
# dtype: int64

# %%
# membuat list deskripsi barang yang dibeli tiap kode transaksi (InvoiceNo)
x = data.groupby('InvoiceNo')
transaksi = []
for i, j  in x :
    transaksi.append(list(j['Description'].map(str)))

# %%
databaru = pd.DataFrame(transaksi)

# %%
databaru.shape
# Out:
# (19168, 923)

# %%
records=[]
for i in range (0,19168): 
    records.append([str(databaru.values[i,j]) for j in range (0, 923)])

# %%
# association rule
association_rules=apriori(records,min_support=0.008, 
                          min_confidence=0.7, 
                          min_lift=6, min_length=2) 

association_result=list(association_rules)

# %%
association_result[0]
# Out:
# RelationRecord(items=frozenset({'PAINTED METAL PEARS ASSORTED', 'ASSORTED COLOUR BIRD ORNAMENT'}), support=0.013512103505843072, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PAINTED METAL PEARS ASSORTED'}), items_add=frozenset({'ASSORTED COLOUR BIRD ORNAMENT'}), confidence=0.7214484679665737, lift=9.504277824043495)])

# %%
for item in association_result:
    #first index of the inner list
    #contains base item and add item
    pair = item[0]
    items=[x for x in pair]
    print("rule: " + items[0] + "->" + items[1])
    
    #second index of inner list
    print("support: " + str(item[1]))
    
    #third index of the list located at 10th
    #of the third index of the inner list
    
    print("confidence: " + str(item[2][0][2]))
    print("lift: " + str(item[2][0][3]))
    print("==========================================================================")
# Out:
# rule: PAINTED METAL PEARS ASSORTED->ASSORTED COLOUR BIRD ORNAMENT
# support: 0.013512103505843072
# confidence: 0.7214484679665737
# lift: 9.504277824043495
# ==========================================================================
# rule: BAKING SET SPACEBOY DESIGN->BAKING SET 9 PIECE RETROSPOT
# support: 0.016016277128547578
# confidence: 0.7309523809523809
# lift: 16.216313932980597
# ==========================================================================
# rule: JUMBO BAG RED RETROSPOT->BATHROOM METAL SIGN
# support: 0.009442821368948248
# confidence: 0.7182539682539684
# lift: 13.604241169458563
# ==========================================================================
# rule: BLUE HAPPY BIRTHDAY BUNTING->PINK HAPPY BIRTHDAY BUNTING
# support: 0.013459933222036728
# confidence: 0.7206703910614525
# lift: 38.05457315665543
# ==========================================================================
# rule: WHITE HANGING HEART T-LIGHT HOLDER->CANDLEHOLDER PINK HANGING HEART
# support: 0.014712020033388982
# confidence: 0.7085427135678392
# lift: 6.0201005025125625
# ==========================================================================
# rule: CHARLOTTE BAG SUKI DESIGN->CHARLOTTE BAG PINK POLKADOT
# support: 0.00975584307178631
# confidence: 0.7030075187969924
# lift: 45.83417727993453
# ==========================================================================
# rule: CHARLOTTE BAG PINK POLKADOT->RED RETROSPOT CHARLOTTE BAG
# support: 0.010590567612687812
# confidence: 0.763157894736842
# lift: 49.925633195617024
# ==========================================================================
# rule: STRAWBERRY CHARLOTTE BAG->CHARLOTTE BAG PINK POLKADOT
# support: 0.009181969949916527
# confidence: 0.7553648068669527
# lift: 54.43170157152537
# ==========================================================================
# rule: CHARLOTTE BAG PINK POLKADOT->WOODLAND CHARLOTTE BAG
# support: 0.010381886477462438
# confidence: 0.7481203007518797
# lift: 47.79989974937344
# ==========================================================================
# rule: CHARLOTTE BAG SUKI DESIGN->RED RETROSPOT CHARLOTTE BAG
# support: 0.010799248747913189
# confidence: 0.7040816326530612
# lift: 46.060876227624156
# ==========================================================================
# rule: STRAWBERRY CHARLOTTE BAG->CHARLOTTE BAG SUKI DESIGN
# support: 0.009442821368948248
# confidence: 0.776824034334764
# lift: 50.64681323173046
# ==========================================================================
# rule: CHARLOTTE BAG SUKI DESIGN->WOODLAND CHARLOTTE BAG
# support: 0.011007929883138564
# confidence: 0.717687074829932
# lift: 45.85541950113379
# ==========================================================================
# rule: CHILDRENS CUTLERY DOLLY GIRL ->CHILDRENS CUTLERY SPACEBOY
# support: 0.011529632721202004
# confidence: 0.7594501718213059
# lift: 40.43650248186331
# ==========================================================================
# rule: CHILDRENS CUTLERY POLKADOT PINK->CHILDRENS CUTLERY POLKADOT BLUE
# support: 0.011477462437395659
# confidence: 0.7612456747404843
# lift: 34.49540684024966
# ==========================================================================
# rule: COFFEE MUG APPLES DESIGN->COFFEE MUG PEARS  DESIGN
# support: 0.008399415692821368
# confidence: 0.7594339622641509
# lift: 55.9878084179971
# ==========================================================================
# rule: DOTCOM POSTAGE->LOVEBIRD HANGING DECORATION WHITE
# support: 0.008921118530884809
# confidence: 0.7245762711864407
# lift: 27.447980170161458
# ==========================================================================
# rule: GARDENERS KNEELING PAD KEEP CALM ->GARDENERS KNEELING PAD CUP OF TEA
# support: 0.028484974958263774
# confidence: 0.7203166226912928
# lift: 15.122704297641514
# ==========================================================================
# rule: PINK REGENCY TEACUP AND SAUCER->GREEN REGENCY TEACUP AND SAUCER
# support: 0.03297161936560935
# confidence: 0.8261437908496732
# lift: 15.63230422804199
# ==========================================================================
# rule: ROSES REGENCY TEACUP AND SAUCER ->GREEN REGENCY TEACUP AND SAUCER
# support: 0.040014607679465776
# confidence: 0.7571569595261599
# lift: 13.627403380467074
# ==========================================================================
# rule: MONSTERS STENCIL CRAFT->HAPPY STENCIL CRAFT
# support: 0.008295075125208681
# confidence: 0.7681159420289855
# lift: 54.530542136339236
# ==========================================================================
# rule: JUMBO BAG DOLLY GIRL DESIGN->JUMBO BAG RED RETROSPOT
# support: 0.008190734557595994
# confidence: 0.7136363636363637
# lift: 13.516780452748835
# ==========================================================================
# rule: JUMBO BAG PINK POLKADOT->JUMBO BAG RED RETROSPOT
# support: 0.022120200333889815
# confidence: 0.703150912106136
# lift: 13.31817854076128
# ==========================================================================
# rule: JUMBO BAG SCANDINAVIAN BLUE PAISLEY->JUMBO BAG RED RETROSPOT
# support: 0.011790484140233723
# confidence: 0.7661016949152543
# lift: 14.510511154284185
# ==========================================================================
# rule: JUMBO BAG SPACEBOY DESIGN->JUMBO BAG RED RETROSPOT
# support: 0.012729549248747913
# confidence: 0.7134502923976608
# lift: 13.513256131105102
# ==========================================================================
# rule: JUMBO BAG TOYS ->JUMBO BAG RED RETROSPOT
# support: 0.013981636060100167
# confidence: 0.7382920110192837
# lift: 13.983775955748646
# ==========================================================================
# rule: SET/20 RED RETROSPOT PAPER NAPKINS ->JUMBO BAG RED RETROSPOT
# support: 0.008451585976627712
# confidence: 0.7074235807860261
# lift: 13.399105925401727
# ==========================================================================
# rule: SMALL HEART MEASURING SPOONS->JUMBO BAG RED RETROSPOT
# support: 0.008608096828046745
# confidence: 0.7236842105263158
# lift: 13.707093821510298
# ==========================================================================
# rule: PINK REGENCY TEACUP AND SAUCER->ROSES REGENCY TEACUP AND SAUCER
# support: 0.031197829716193656
# confidence: 0.7816993464052288
# lift: 14.069120255300868
# ==========================================================================
# rule: POPPY'S PLAYHOUSE BATHROOM->POPPY'S PLAYHOUSE BEDROOM
# support: 0.009860183639398999
# confidence: 0.8325991189427313
# lift: 37.72874683662949
# ==========================================================================
# rule: POPPY'S PLAYHOUSE BATHROOM->POPPY'S PLAYHOUSE KITCHEN
# support: 0.01001669449081803
# confidence: 0.8458149779735683
# lift: 37.35617856635336
# ==========================================================================
# rule: POPPY'S PLAYHOUSE LIVINGROOM ->POPPY'S PLAYHOUSE BATHROOM
# support: 0.00975584307178631
# confidence: 0.8237885462555066
# lift: 48.288620350536846
# ==========================================================================
# rule: POPPY'S PLAYHOUSE KITCHEN->POPPY'S PLAYHOUSE BEDROOM
# support: 0.0162771285475793
# confidence: 0.7375886524822696
# lift: 32.57626564695885
# ==========================================================================
# rule: POPPY'S PLAYHOUSE LIVINGROOM ->POPPY'S PLAYHOUSE BEDROOM
# support: 0.013564273789649415
# confidence: 0.7951070336391437
# lift: 36.02981470637141
# ==========================================================================
# rule: POPPY'S PLAYHOUSE LIVINGROOM ->POPPY'S PLAYHOUSE KITCHEN
# support: 0.013668614357262103
# confidence: 0.801223241590214
# lift: 35.386744458067334
# ==========================================================================
# rule: STRAWBERRY CHARLOTTE BAG->RED RETROSPOT CHARLOTTE BAG
# support: 0.009912353923205343
# confidence: 0.8154506437768241
# lift: 53.34661412939988
# ==========================================================================
# rule: WOODLAND CHARLOTTE BAG->RED RETROSPOT CHARLOTTE BAG
# support: 0.011164440734557596
# confidence: 0.7303754266211605
# lift: 46.66612059158135
# ==========================================================================
# rule: REGENCY MILK JUG PINK ->REGENCY SUGAR BOWL GREEN
# support: 0.012677378964941569
# confidence: 0.7386018237082066
# lift: 43.96745266099039
# ==========================================================================
# rule: REGENCY TEAPOT ROSES ->REGENCY SUGAR BOWL GREEN
# support: 0.01215567612687813
# confidence: 0.7236024844720498
# lift: 33.42171668038615
# ==========================================================================
# rule: REGENCY TEA PLATE PINK->REGENCY TEA PLATE GREEN
# support: 0.014503338898163605
# confidence: 0.7296587926509186
# lift: 45.856064713222324
# ==========================================================================
# rule: REGENCY TEA PLATE GREEN ->REGENCY TEA PLATE ROSES
# support: 0.016642320534223706
# confidence: 0.837270341207349
# lift: 36.06471438261228
# ==========================================================================
# rule: REGENCY TEA PLATE PINK->REGENCY TEA PLATE ROSES
# support: 0.01403380634390651
# confidence: 0.8819672131147541
# lift: 37.989994474120465
# ==========================================================================
# rule: ROLL WRAP 50'S CHRISTMAS->ROLL WRAP 50'S RED CHRISTMAS
# support: 0.008868948247078463
# confidence: 0.8095238095238095
# lift: 44.8466831819433
# ==========================================================================
# rule: SET OF 3 WOODEN HEART DECORATIONS->SET OF 3 WOODEN TREE DECORATIONS
# support: 0.01095575959933222
# confidence: 0.7191780821917808
# lift: 31.330012453300125
# ==========================================================================
# rule: SET OF 3 WOODEN STOCKING DECORATION->SET OF 3 WOODEN TREE DECORATIONS
# support: 0.011373121869782971
# confidence: 0.7465753424657534
# lift: 45.14307938291344
# ==========================================================================
# rule: SET/10 PINK POLKADOT PARTY CANDLES->SET/10 BLUE POLKADOT PARTY CANDLES
# support: 0.009599332220367279
# confidence: 0.7763713080168777
# lift: 43.76907421196327
# ==========================================================================
# rule: STRAWBERRY CHARLOTTE BAG->WOODLAND CHARLOTTE BAG
# support: 0.01001669449081803
# confidence: 0.8240343347639485
# lift: 52.65030042918455
# ==========================================================================
# rule: ALARM CLOCK BAKELIKE CHOCOLATE->ALARM CLOCK BAKELIKE GREEN
# support: 0.008086393989983306
# confidence: 0.7045454545454547
# lift: 13.780333951762527
# ==========================================================================
# rule: ALARM CLOCK BAKELIKE CHOCOLATE->ALARM CLOCK BAKELIKE GREEN
# support: 0.011738313856427379
# confidence: 0.8122743682310469
# lift: 14.814153273313707
# ==========================================================================
# rule: ALARM CLOCK BAKELIKE CHOCOLATE->ALARM CLOCK BAKELIKE RED
# support: 0.008973288814691152
# confidence: 0.781818181818182
# lift: 14.258697344520373
# ==========================================================================
# rule: ALARM CLOCK BAKELIKE IVORY->ALARM CLOCK BAKELIKE GREEN
# support: 0.013564273789649415
# confidence: 0.7784431137724551
# lift: 14.197143296660721
# ==========================================================================
# rule: ALARM CLOCK BAKELIKE GREEN->ALARM CLOCK BAKELIKE RED
# support: 0.010851419031719533
# confidence: 0.7619047619047619
# lift: 13.895519006841555
# ==========================================================================
# rule: ALARM CLOCK BAKELIKE GREEN->ALARM CLOCK BAKELIKE RED
# support: 0.016329298831385643
# confidence: 0.7488038277511962
# lift: 13.656585889947602
# ==========================================================================
# rule: ALARM CLOCK BAKELIKE GREEN->ALARM CLOCK BAKELIKE RED
# support: 0.008973288814691152
# confidence: 0.7049180327868854
# lift: 12.856202523747877
# ==========================================================================
# rule: ALARM CLOCK BAKELIKE IVORY->ALARM CLOCK BAKELIKE RED
# support: 0.010747078464106845
# confidence: 0.7545787545787546
# lift: 13.761908247160386
# ==========================================================================
# rule: ALARM CLOCK BAKELIKE PINK->ALARM CLOCK BAKELIKE RED
# support: 0.008868948247078463
# confidence: 0.787037037037037
# lift: 14.353878140747787
# ==========================================================================
# rule: PAINTED METAL PEARS ASSORTED->ASSORTED COLOUR BIRD ORNAMENT
# support: 0.013512103505843072
# confidence: 0.7214484679665737
# lift: 9.504277824043495
# ==========================================================================
# rule: BAKING SET SPACEBOY DESIGN->BAKING SET 9 PIECE RETROSPOT
# support: 0.016016277128547578
# confidence: 0.7309523809523809
# lift: 16.216313932980597
# ==========================================================================
# rule: JUMBO BAG RED RETROSPOT->None
# support: 0.009390651085141904
# confidence: 0.7171314741035857
# lift: 13.582980331637877
# ==========================================================================
# rule: PINK HAPPY BIRTHDAY BUNTING->BLUE HAPPY BIRTHDAY BUNTING
# support: 0.013459933222036728
# confidence: 0.7206703910614525
# lift: 38.05457315665543
# ==========================================================================
# rule: BLUE STRIPE CERAMIC DRAWER KNOB->RED STRIPE CERAMIC DRAWER KNOB
# support: 0.008034223706176962
# confidence: 0.7439613526570049
# lift: 33.95297906602255
# ==========================================================================
# rule: WHITE HANGING HEART T-LIGHT HOLDER->CANDLEHOLDER PINK HANGING HEART
# support: 0.014712020033388982
# confidence: 0.7085427135678392
# lift: 6.0201005025125625
# ==========================================================================
# rule: CHARLOTTE BAG SUKI DESIGN->CHARLOTTE BAG PINK POLKADOT
# support: 0.00975584307178631
# confidence: 0.7030075187969924
# lift: 45.83417727993453
# ==========================================================================
# rule: CHARLOTTE BAG SUKI DESIGN->CHARLOTTE BAG PINK POLKADOT
# support: 0.008347245409015025
# confidence: 0.8556149732620321
# lift: 55.97415633954481
# ==========================================================================
# rule: CHARLOTTE BAG SUKI DESIGN->CHARLOTTE BAG PINK POLKADOT
# support: 0.008347245409015025
# confidence: 0.8556149732620321
# lift: 54.6680926916221
# ==========================================================================
# rule: CHARLOTTE BAG PINK POLKADOT->None
# support: 0.010590567612687812
# confidence: 0.763157894736842
# lift: 49.925633195617024
# ==========================================================================
# rule: STRAWBERRY CHARLOTTE BAG->CHARLOTTE BAG PINK POLKADOT
# support: 0.009181969949916527
# confidence: 0.7553648068669527
# lift: 54.43170157152537
# ==========================================================================
# rule: CHARLOTTE BAG PINK POLKADOT->WOODLAND CHARLOTTE BAG
# support: 0.010381886477462438
# confidence: 0.7481203007518797
# lift: 47.79989974937344
# ==========================================================================
# rule: STRAWBERRY CHARLOTTE BAG->CHARLOTTE BAG PINK POLKADOT
# support: 0.008347245409015025
# confidence: 0.7881773399014779
# lift: 64.840271464513
# ==========================================================================
# rule: CHARLOTTE BAG PINK POLKADOT->WOODLAND CHARLOTTE BAG
# support: 0.008921118530884809
# confidence: 0.8423645320197045
# lift: 53.82147783251232
# ==========================================================================
# rule: STRAWBERRY CHARLOTTE BAG->CHARLOTTE BAG PINK POLKADOT
# support: 0.008034223706176962
# confidence: 0.8750000000000001
# lift: 55.90666666666667
# ==========================================================================
# rule: CHARLOTTE BAG SUKI DESIGN->None
# support: 0.010799248747913189
# confidence: 0.7040816326530612
# lift: 46.060876227624156
# ==========================================================================
# rule: STRAWBERRY CHARLOTTE BAG->CHARLOTTE BAG SUKI DESIGN
# support: 0.009442821368948248
# confidence: 0.776824034334764
# lift: 50.64681323173046
# ==========================================================================
# rule: CHARLOTTE BAG SUKI DESIGN->WOODLAND CHARLOTTE BAG
# support: 0.011007929883138564
# confidence: 0.717687074829932
# lift: 45.85541950113379
# ==========================================================================
# rule: STRAWBERRY CHARLOTTE BAG->CHARLOTTE BAG SUKI DESIGN
# support: 0.008295075125208681
# confidence: 0.7681159420289855
# lift: 63.1898986129253
# ==========================================================================
# rule: CHARLOTTE BAG SUKI DESIGN->WOODLAND CHARLOTTE BAG
# support: 0.008868948247078463
# confidence: 0.8212560386473429
# lift: 52.47278582930756
# ==========================================================================
# rule: CHARLOTTE BAG SUKI DESIGN->WOODLAND CHARLOTTE BAG
# support: 0.008295075125208681
# confidence: 0.8457446808510638
# lift: 54.03744680851064
# ==========================================================================
# rule: STRAWBERRY CHARLOTTE BAG->CHARLOTTE BAG SUKI DESIGN
# support: 0.008399415692821368
# confidence: 0.8895027624309392
# lift: 56.83329650092081
# ==========================================================================
# rule: CHILDRENS CUTLERY DOLLY GIRL ->CHILDRENS CUTLERY SPACEBOY
# support: 0.011529632721202004
# confidence: 0.7594501718213059
# lift: 40.43650248186331
# ==========================================================================
# rule: CHILDRENS CUTLERY POLKADOT PINK->None
# support: 0.011477462437395659
# confidence: 0.7612456747404843
# lift: 34.49540684024966
# ==========================================================================
# rule: None->COFFEE MUG APPLES DESIGN
# support: 0.008399415692821368
# confidence: 0.7594339622641509
# lift: 55.9878084179971
# ==========================================================================
# rule: SPACEBOY LUNCH BOX ->DOLLY GIRL LUNCH BOX
# support: 0.009494991652754591
# confidence: 0.7109375
# lift: 15.141388888888889
# ==========================================================================
# rule: ROSES REGENCY TEACUP AND SAUCER ->DOTCOM POSTAGE
# support: 0.008608096828046745
# confidence: 0.717391304347826
# lift: 12.911696264543783
# ==========================================================================
# rule: DOTCOM POSTAGE->JUMBO BAG PINK POLKADOT
# support: 0.00975584307178631
# confidence: 0.8130434782608694
# lift: 15.399621928166349
# ==========================================================================
# rule: DOTCOM POSTAGE->JUMBO BAG WOODLAND ANIMALS
# support: 0.008451585976627712
# confidence: 0.7043478260869565
# lift: 26.31762013729977
# ==========================================================================
# rule: DOTCOM POSTAGE->JUMBO BAG WOODLAND ANIMALS
# support: 0.010381886477462438
# confidence: 0.7683397683397684
# lift: 14.552901857249685
# ==========================================================================
# rule: DOTCOM POSTAGE->JUMBO SHOPPER VINTAGE RED PAISLEY
# support: 0.010381886477462438
# confidence: 0.77431906614786
# lift: 14.66615401178081
# ==========================================================================
# rule: DOTCOM POSTAGE->JUMBO STORAGE BAG SUKI
# support: 0.01027754590984975
# confidence: 0.7296296296296297
# lift: 13.81970428926951
# ==========================================================================
# rule: DOTCOM POSTAGE->RECYCLING BAG RETROSPOT
# support: 0.009390651085141904
# confidence: 0.759493670886076
# lift: 14.38535047781058
# ==========================================================================
# rule: DOTCOM POSTAGE->RED TOADSTOOL LED NIGHT LIGHT
# support: 0.008190734557595994
# confidence: 0.7370892018779343
# lift: 13.96099389485795
# ==========================================================================
# rule: DOTCOM POSTAGE->SUKI  SHOULDER BAG
# support: 0.008973288814691152
# confidence: 0.7226890756302521
# lift: 13.688245258577739
# ==========================================================================
# rule: DOTCOM POSTAGE->LOVEBIRD HANGING DECORATION WHITE
# support: 0.008921118530884809
# confidence: 0.7276595744680852
# lift: 27.564780085779166
# ==========================================================================
# rule: GARDENERS KNEELING PAD KEEP CALM ->GARDENERS KNEELING PAD CUP OF TEA
# support: 0.02843280467445743
# confidence: 0.7199471598414795
# lift: 15.114947601140722
# ==========================================================================
# rule: PINK REGENCY TEACUP AND SAUCER->JAM MAKING SET PRINTED
# support: 0.008190734557595994
# confidence: 0.8820224719101124
# lift: 16.689641403329748
# ==========================================================================
# rule: ROSES REGENCY TEACUP AND SAUCER ->JAM MAKING SET PRINTED
# support: 0.010538397328881469
# confidence: 0.792156862745098
# lift: 14.257335910890177
# ==========================================================================
# rule: PINK REGENCY TEACUP AND SAUCER->JAM MAKING SET WITH JARS
# support: 0.008242904841402337
# confidence: 0.88268156424581
# lift: 16.702112757614696
# ==========================================================================
# rule: ROSES REGENCY TEACUP AND SAUCER ->JAM MAKING SET WITH JARS
# support: 0.010903589315525876
# confidence: 0.8038461538461539
# lift: 14.467721198988805
# ==========================================================================
# rule: ROSES REGENCY TEACUP AND SAUCER ->GREEN REGENCY TEACUP AND SAUCER
# support: 0.008921118530884809
# confidence: 0.7125
# lift: 12.823661971830987
# ==========================================================================
# rule: ROSES REGENCY TEACUP AND SAUCER ->NATURAL SLATE HEART CHALKBOARD
# support: 0.00813856427378965
# confidence: 0.7393364928909953
# lift: 13.306668446699154
# ==========================================================================
# rule: PINK REGENCY TEACUP AND SAUCER->None
# support: 0.032919449081803005
# confidence: 0.8259162303664922
# lift: 15.627998325434278
# ==========================================================================
# rule: ROSES REGENCY TEACUP AND SAUCER ->None
# support: 0.03996243739565943
# confidence: 0.7569169960474309
# lift: 13.623084488485592
# ==========================================================================
# rule: PINK REGENCY TEACUP AND SAUCER->REGENCY CAKESTAND 3 TIER
# support: 0.01549457429048414
# confidence: 0.881305637982196
# lift: 16.67607746183883
# ==========================================================================
# rule: PINK REGENCY TEACUP AND SAUCER->REGENCY TEA PLATE GREEN
# support: 0.009599332220367279
# confidence: 0.757201646090535
# lift: 18.972602813416177
# ==========================================================================
# rule: PINK REGENCY TEACUP AND SAUCER->GREEN REGENCY TEACUP AND SAUCER
# support: 0.008451585976627712
# confidence: 0.8852459016393441
# lift: 22.18090646094503
# ==========================================================================
# rule: PINK REGENCY TEACUP AND SAUCER->REGENCY TEA PLATE ROSES
# support: 0.00907762938230384
# confidence: 0.7767857142857143
# lift: 19.463305322128853
# ==========================================================================
# rule: PINK REGENCY TEACUP AND SAUCER->ROSES REGENCY TEACUP AND SAUCER
# support: 0.028224123539232055
# confidence: 0.8560126582278481
# lift: 15.406620312592857
# ==========================================================================
# rule: PINK REGENCY TEACUP AND SAUCER->WHITE HANGING HEART T-LIGHT HOLDER
# support: 0.008295075125208681
# confidence: 0.8368421052631578
# lift: 15.834737881228243
# ==========================================================================
# rule: ROSES REGENCY TEACUP AND SAUCER ->RECIPE BOX PANTRY YELLOW DESIGN
# support: 0.008868948247078463
# confidence: 0.7692307692307692
# lift: 13.844709281329
# ==========================================================================
# rule: ROSES REGENCY TEACUP AND SAUCER ->REGENCY CAKESTAND 3 TIER
# support: 0.018050918196994992
# confidence: 0.7881548974943053
# lift: 14.18530805180361
# ==========================================================================
# rule: REGENCY TEA PLATE PINK->REGENCY TEA PLATE GREEN
# support: 0.009129799666110184
# confidence: 0.720164609053498
# lift: 45.25939418471295
# ==========================================================================
# rule: REGENCY TEA PLATE GREEN ->REGENCY TEA PLATE ROSES
# support: 0.010486227045075125
# confidence: 0.8271604938271605
# lift: 35.62924122624497
# ==========================================================================
# rule: ROSES REGENCY TEACUP AND SAUCER ->REGENCY TEA PLATE GREEN
# support: 0.010434056761268781
# confidence: 0.823045267489712
# lift: 14.813269189899342
# ==========================================================================
# rule: REGENCY TEA PLATE PINK->REGENCY TEA PLATE ROSES
# support: 0.008608096828046745
# confidence: 0.9016393442622951
# lift: 38.837354945662184
# ==========================================================================
# rule: REGENCY TEA PLATE PINK->ROSES REGENCY TEACUP AND SAUCER
# support: 0.008451585976627712
# confidence: 0.8852459016393441
# lift: 15.932763795890093
# ==========================================================================
# rule: ROSES REGENCY TEACUP AND SAUCER ->REGENCY TEA PLATE ROSES
# support: 0.010590567612687812
# confidence: 0.9062499999999999
# lift: 16.310798122065727
# ==========================================================================
# rule: REGENCY TEAPOT ROSES ->GREEN REGENCY TEACUP AND SAUCER
# support: 0.008921118530884809
# confidence: 0.8814432989690723
# lift: 15.864324088863077
# ==========================================================================
# rule: WHITE HANGING HEART T-LIGHT HOLDER->ROSES REGENCY TEACUP AND SAUCER
# support: 0.010434056761268781
# confidence: 0.7434944237918216
# lift: 13.381503394593086
# ==========================================================================
# rule: MONSTERS STENCIL CRAFT->HAPPY STENCIL CRAFT
# support: 0.008295075125208681
# confidence: 0.7718446601941747
# lift: 54.79525350593312
# ==========================================================================
# rule: SUKI  SHOULDER BAG->JAM MAKING SET PRINTED
# support: 0.008086393989983306
# confidence: 0.7110091743119267
# lift: 13.467019617797442
# ==========================================================================
# rule: SKULL SHOULDER BAG->SUKI  SHOULDER BAG
# support: 0.008034223706176962
# confidence: 0.911242603550296
# lift: 32.956034386513345
# ==========================================================================
# rule: PINK REGENCY TEACUP AND SAUCER->ROSES REGENCY TEACUP AND SAUCER
# support: 0.008034223706176962
# confidence: 0.8603351955307262
# lift: 15.484417866603719
# ==========================================================================
# rule: JUMBO  BAG BAROQUE BLACK WHITE->JUMBO BAG OWLS
# support: 0.008347245409015025
# confidence: 0.7881773399014779
# lift: 14.92863957631574
# ==========================================================================
# rule: JUMBO  BAG BAROQUE BLACK WHITE->JUMBO BAG PINK POLKADOT
# support: 0.010486227045075125
# confidence: 0.8072289156626505
# lift: 15.28948997571313
# ==========================================================================
# rule: JUMBO  BAG BAROQUE BLACK WHITE->JUMBO BAG WOODLAND ANIMALS
# support: 0.008086393989983306
# confidence: 0.7077625570776257
# lift: 22.49816367174781
# ==========================================================================
# rule: JUMBO  BAG BAROQUE BLACK WHITE->JUMBO BAG WOODLAND ANIMALS
# support: 0.009286310517529215
# confidence: 0.8127853881278538
# lift: 15.394733517425596
# ==========================================================================
# rule: JUMBO  BAG BAROQUE BLACK WHITE->JUMBO SHOPPER VINTAGE RED PAISLEY
# support: 0.009703672787979966
# confidence: 0.7654320987654321
# lift: 14.497828526814034
# ==========================================================================
# rule: JUMBO  BAG BAROQUE BLACK WHITE->JUMBO STORAGE BAG SUKI
# support: 0.010434056761268781
# confidence: 0.823045267489712
# lift: 15.589062932058102
# ==========================================================================
# rule: JUMBO BAG DOLLY GIRL DESIGN->None
# support: 0.00813856427378965
# confidence: 0.7123287671232877
# lift: 13.492013644485356
# ==========================================================================
# rule: JUMBO BAG PINK POLKADOT->JUMBO BAG OWLS
# support: 0.008451585976627712
# confidence: 0.8019801980198019
# lift: 15.19007552929206
# ==========================================================================
# rule: JUMBO BAG WOODLAND ANIMALS->JUMBO BAG OWLS
# support: 0.008295075125208681
# confidence: 0.7395348837209302
# lift: 14.00731684897509
# ==========================================================================
# rule: JUMBO SHOPPER VINTAGE RED PAISLEY->JUMBO BAG OWLS
# support: 0.008086393989983306
# confidence: 0.8031088082901555
# lift: 15.211452210776384
# ==========================================================================
# rule: JUMBO STORAGE BAG SUKI->JUMBO BAG OWLS
# support: 0.00907762938230384
# confidence: 0.7631578947368421
# lift: 14.45475348450177
# ==========================================================================
# rule: JUMBO BAG PINK VINTAGE PAISLEY->JUMBO BAG PINK POLKADOT
# support: 0.008347245409015025
# confidence: 0.8040201005025125
# lift: 15.228712733628617
# ==========================================================================
# rule: JUMBO BAG SPACEBOY DESIGN->JUMBO BAG PINK POLKADOT
# support: 0.008399415692821368
# confidence: 0.8214285714285713
# lift: 15.558441558441556
# ==========================================================================
# rule: JUMBO BAG TOYS ->JUMBO BAG PINK POLKADOT
# support: 0.009547161936560935
# confidence: 0.8591549295774648
# lift: 16.27300562266882
# ==========================================================================
# rule: JUMBO BAG WOODLAND ANIMALS->JUMBO BAG PINK POLKADOT
# support: 0.011999165275459099
# confidence: 0.7986111111111112
# lift: 15.126262626262628
# ==========================================================================
# rule: JUMBO SHOPPER VINTAGE RED PAISLEY->JUMBO BAG PINK POLKADOT
# support: 0.012364357262103505
# confidence: 0.820069204152249
# lift: 15.53269417508924
# ==========================================================================
# rule: JUMBO STORAGE BAG SUKI->JUMBO BAG PINK POLKADOT
# support: 0.013668614357262103
# confidence: 0.8136645962732919
# lift: 15.411386345223775
# ==========================================================================
# rule: None->JUMBO BAG PINK POLKADOT
# support: 0.02206803005008347
# confidence: 0.7026578073089701
# lift: 13.30883878507741
# ==========================================================================
# rule: RECYCLING BAG RETROSPOT ->JUMBO BAG PINK POLKADOT
# support: 0.009129799666110184
# confidence: 0.8064516129032258
# lift: 15.274767308427897
# ==========================================================================
# rule: JUMBO BAG TOYS ->JUMBO BAG WOODLAND ANIMALS
# support: 0.008503756260434057
# confidence: 0.7652582159624414
# lift: 28.593507765239913
# ==========================================================================
# rule: JUMBO BAG TOYS ->JUMBO STORAGE BAG SUKI
# support: 0.008399415692821368
# confidence: 0.7558685446009389
# lift: 22.888607050412002
# ==========================================================================
# rule: JUMBO STORAGE BAG SUKI->JUMBO BAG WOODLAND ANIMALS
# support: 0.01095575959933222
# confidence: 0.7291666666666666
# lift: 22.08004212743549
# ==========================================================================
# rule: JUMBO SHOPPER VINTAGE RED PAISLEY->JUMBO STORAGE BAG SUKI
# support: 0.01095575959933222
# confidence: 0.7266435986159169
# lift: 22.003640597582773
# ==========================================================================
# rule: JUMBO SHOPPER VINTAGE RED PAISLEY->JUMBO BAG PINK VINTAGE PAISLEY
# support: 0.008921118530884809
# confidence: 0.7434782608695653
# lift: 14.082007217735008
# ==========================================================================
# rule: JUMBO STORAGE BAG SUKI->JUMBO BAG PINK VINTAGE PAISLEY
# support: 0.008868948247078463
# confidence: 0.7623318385650223
# lift: 14.439107392899553
# ==========================================================================
# rule: JUMBO BAG SCANDINAVIAN BLUE PAISLEY->None
# support: 0.011738313856427379
# confidence: 0.7653061224489797
# lift: 14.495442445753007
# ==========================================================================
# rule: JUMBO STORAGE BAG SUKI->JUMBO BAG SPACEBOY DESIGN
# support: 0.008347245409015025
# confidence: 0.7881773399014779
# lift: 14.92863957631574
# ==========================================================================
# rule: JUMBO BAG SPACEBOY DESIGN->None
# support: 0.012677378964941569
# confidence: 0.7126099706744868
# lift: 13.497339839810834
# ==========================================================================
# rule: JUMBO BAG TOYS ->JUMBO BAG WOODLAND ANIMALS
# support: 0.009651502504173622
# confidence: 0.8222222222222222
# lift: 15.573473869126044
# ==========================================================================
# rule: JUMBO BAG TOYS ->JUMBO SHOPPER VINTAGE RED PAISLEY
# support: 0.00933848080133556
# confidence: 0.8364485981308412
# lift: 15.842931550367554
# ==========================================================================
# rule: JUMBO BAG TOYS ->JUMBO STORAGE BAG SUKI
# support: 0.009547161936560935
# confidence: 0.8169642857142857
# lift: 15.473884810841334
# ==========================================================================
# rule: JUMBO BAG TOYS ->None
# support: 0.013929465776293823
# confidence: 0.7375690607734806
# lift: 13.970082763741184
# ==========================================================================
# rule: JUMBO SHOPPER VINTAGE RED PAISLEY->JUMBO BAG WOODLAND ANIMALS
# support: 0.01215567612687813
# confidence: 0.8118466898954704
# lift: 15.376953905055709
# ==========================================================================
# rule: JUMBO STORAGE BAG SUKI->JUMBO BAG WOODLAND ANIMALS
# support: 0.012573038397328882
# confidence: 0.7602523659305994
# lift: 14.399720701736888
# ==========================================================================
# rule: JUMBO BAG WOODLAND ANIMALS->RECYCLING BAG RETROSPOT
# support: 0.008868948247078463
# confidence: 0.787037037037037
# lift: 14.907041428780559
# ==========================================================================
# rule: JUMBO SHOPPER VINTAGE RED PAISLEY->JUMBO STORAGE BAG SUKI
# support: 0.013564273789649415
# confidence: 0.7647058823529412
# lift: 14.484073471285749
# ==========================================================================
# rule: JUMBO SHOPPER VINTAGE RED PAISLEY->RECYCLING BAG RETROSPOT
# support: 0.008973288814691152
# confidence: 0.8190476190476191
# lift: 15.513344626388108
# ==========================================================================
# rule: JUMBO STORAGE BAG SKULLS->JUMBO STORAGE BAG SUKI
# support: 0.008660267111853089
# confidence: 0.7545454545454546
# lift: 14.291627739849087
# ==========================================================================
# rule: JUMBO STORAGE BAG SUKI->RECYCLING BAG RETROSPOT
# support: 0.00907762938230384
# confidence: 0.7665198237885463
# lift: 14.51843081262733
# ==========================================================================
# rule: WHITE HANGING HEART T-LIGHT HOLDER->JUMBO STORAGE BAG SUKI
# support: 0.008034223706176962
# confidence: 0.7586206896551726
# lift: 14.368815592203902
# ==========================================================================
# rule: SET/20 RED RETROSPOT PAPER NAPKINS ->None
# support: 0.008399415692821368
# confidence: 0.706140350877193
# lift: 13.374800637958533
# ==========================================================================
# rule: SMALL HEART MEASURING SPOONS->None
# support: 0.008555926544240401
# confidence: 0.722466960352423
# lift: 13.684038237188977
# ==========================================================================
# rule: JUMBO BAG TOYS ->JUMBO SHOPPER VINTAGE RED PAISLEY
# support: 0.008608096828046745
# confidence: 0.7333333333333334
# lift: 22.93072321914084
# ==========================================================================
# rule: JUMBO BAG TOYS ->JUMBO STORAGE BAG SUKI
# support: 0.009129799666110184
# confidence: 0.7777777777777778
# lift: 23.552044935931193
# ==========================================================================
# rule: JUMBO BAG TOYS ->JUMBO SHOPPER VINTAGE RED PAISLEY
# support: 0.00907762938230384
# confidence: 0.8130841121495327
# lift: 24.621163130619657
# ==========================================================================
# rule: JUMBO SHOPPER VINTAGE RED PAISLEY->JUMBO STORAGE BAG SUKI
# support: 0.011112270450751253
# confidence: 0.7421602787456447
# lift: 22.473504301732255
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->LUNCH BAG DOLLY GIRL DESIGN
# support: 0.010434056761268781
# confidence: 0.7547169811320754
# lift: 9.315141722047407
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->LUNCH BAG PINK POLKADOT
# support: 0.015338063439065108
# confidence: 0.708433734939759
# lift: 8.743887850177272
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->LUNCH BAG PINK POLKADOT
# support: 0.008242904841402337
# confidence: 0.7149321266968325
# lift: 8.824094658419115
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->LUNCH BAG PINK POLKADOT
# support: 0.014764190317195326
# confidence: 0.7237851662404092
# lift: 8.933363854794697
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->LUNCH BAG SUKI DESIGN
# support: 0.014242487479131887
# confidence: 0.7017994858611826
# lift: 8.66200421441542
# ==========================================================================
# rule: LUNCH BAG SUKI DESIGN ->LUNCH BAG VINTAGE LEAF DESIGN
# support: 0.009860183639398999
# confidence: 0.7186311787072244
# lift: 12.7073085179521
# ==========================================================================
# rule: PINK REGENCY TEACUP AND SAUCER->ROSES REGENCY TEACUP AND SAUCER
# support: 0.031145659432387313
# confidence: 0.7814136125654451
# lift: 14.063977582774132
# ==========================================================================
# rule: POPPY'S PLAYHOUSE BATHROOM->None
# support: 0.009860183639398999
# confidence: 0.8325991189427313
# lift: 37.72874683662949
# ==========================================================================
# rule: POPPY'S PLAYHOUSE BATHROOM->POPPY'S PLAYHOUSE KITCHEN
# support: 0.01001669449081803
# confidence: 0.8458149779735683
# lift: 37.35617856635336
# ==========================================================================
# rule: POPPY'S PLAYHOUSE LIVINGROOM ->POPPY'S PLAYHOUSE BATHROOM
# support: 0.00975584307178631
# confidence: 0.8237885462555066
# lift: 48.288620350536846
# ==========================================================================
# rule: POPPY'S PLAYHOUSE KITCHEN->None
# support: 0.016224958263772956
# confidence: 0.7369668246445499
# lift: 32.54880206172058
# ==========================================================================
# rule: POPPY'S PLAYHOUSE LIVINGROOM ->None
# support: 0.013512103505843072
# confidence: 0.7944785276073619
# lift: 36.00133431956954
# ==========================================================================
# rule: POPPY'S PLAYHOUSE LIVINGROOM ->POPPY'S PLAYHOUSE KITCHEN
# support: 0.013616444073455759
# confidence: 0.8006134969325153
# lift: 35.35981453733284
# ==========================================================================
# rule: STRAWBERRY CHARLOTTE BAG->None
# support: 0.009912353923205343
# confidence: 0.8154506437768241
# lift: 53.34661412939988
# ==========================================================================
# rule: WOODLAND CHARLOTTE BAG->None
# support: 0.011164440734557596
# confidence: 0.7303754266211605
# lift: 46.66612059158135
# ==========================================================================
# rule: REGENCY MILK JUG PINK ->REGENCY SUGAR BOWL GREEN
# support: 0.012677378964941569
# confidence: 0.7408536585365852
# lift: 44.1014997727617
# ==========================================================================
# rule: REGENCY TEAPOT ROSES ->REGENCY SUGAR BOWL GREEN
# support: 0.01215567612687813
# confidence: 0.7236024844720498
# lift: 33.42171668038615
# ==========================================================================
# rule: REGENCY TEA PLATE PINK->REGENCY TEA PLATE GREEN
# support: 0.014451168614357262
# confidence: 0.7289473684210526
# lift: 45.81135461604832
# ==========================================================================
# rule: REGENCY TEA PLATE GREEN ->None
# support: 0.016590150250417362
# confidence: 0.8368421052631578
# lift: 36.046268480189234
# ==========================================================================
# rule: REGENCY TEA PLATE PINK->None
# support: 0.013981636060100167
# confidence: 0.8815789473684211
# lift: 37.97327025428741
# ==========================================================================
# rule: ROLL WRAP 50'S CHRISTMAS->None
# support: 0.00881677796327212
# confidence: 0.8086124401913876
# lift: 44.796194374533286
# ==========================================================================
# rule: SET OF 3 WOODEN HEART DECORATIONS->SET OF 3 WOODEN TREE DECORATIONS
# support: 0.010903589315525876
# confidence: 0.718213058419244
# lift: 31.287972508591068
# ==========================================================================
# rule: SET OF 3 WOODEN STOCKING DECORATION->SET OF 3 WOODEN TREE DECORATIONS
# support: 0.011320951585976628
# confidence: 0.7457044673539519
# lift: 45.09042028467051
# ==========================================================================
# rule: SET/10 PINK POLKADOT PARTY CANDLES->None
# support: 0.009599332220367279
# confidence: 0.7763713080168777
# lift: 43.76907421196327
# ==========================================================================
# rule: STRAWBERRY CHARLOTTE BAG->WOODLAND CHARLOTTE BAG
# support: 0.01001669449081803
# confidence: 0.8240343347639485
# lift: 52.65030042918455
# ==========================================================================
# rule: PINK REGENCY TEACUP AND SAUCER->ROSES REGENCY TEACUP AND SAUCER
# support: 0.014607679465776294
# confidence: 0.8308605341246291
# lift: 14.95392931277079
# ==========================================================================
# rule: PINK REGENCY TEACUP AND SAUCER->REGENCY TEA PLATE GREEN
# support: 0.008712437395659432
# confidence: 0.8434343434343434
# lift: 53.00639178671966
# ==========================================================================
# rule: PINK REGENCY TEACUP AND SAUCER->REGENCY TEA PLATE GREEN
# support: 0.00881677796327212
# confidence: 0.8535353535353535
# lift: 36.76531608217001
# ==========================================================================
# rule: PINK REGENCY TEACUP AND SAUCER->ROSES REGENCY TEACUP AND SAUCER
# support: 0.00907762938230384
# confidence: 0.8787878787878788
# lift: 15.81653151230616
# ==========================================================================
# rule: PINK REGENCY TEACUP AND SAUCER->REGENCY TEA PLATE ROSES
# support: 0.008399415692821368
# confidence: 0.8609625668449198
# lift: 37.08523703659196
# ==========================================================================
# rule: PINK REGENCY TEACUP AND SAUCER->ROSES REGENCY TEACUP AND SAUCER
# support: 0.008503756260434057
# confidence: 0.8716577540106953
# lift: 15.688202656222543
# ==========================================================================
# rule: PINK REGENCY TEACUP AND SAUCER->ROSES REGENCY TEACUP AND SAUCER
# support: 0.009547161936560935
# confidence: 0.9014778325123153
# lift: 16.22490806910428
# ==========================================================================
# rule: PINK REGENCY TEACUP AND SAUCER->REGENCY TEAPOT ROSES
# support: 0.008190734557595994
# confidence: 0.907514450867052
# lift: 16.333555863117045
# ==========================================================================
# rule: POPPY'S PLAYHOUSE BATHROOM->POPPY'S PLAYHOUSE KITCHEN
# support: 0.008868948247078463
# confidence: 0.8994708994708993
# lift: 39.72594055543364
# ==========================================================================
# rule: POPPY'S PLAYHOUSE LIVINGROOM ->POPPY'S PLAYHOUSE BATHROOM
# support: 0.008712437395659432
# confidence: 0.8835978835978835
# lift: 51.794508357199476
# ==========================================================================
# rule: POPPY'S PLAYHOUSE LIVINGROOM ->POPPY'S PLAYHOUSE BATHROOM
# support: 0.008712437395659432
# confidence: 0.8697916666666666
# lift: 50.98521916411824
# ==========================================================================
# rule: POPPY'S PLAYHOUSE LIVINGROOM ->POPPY'S PLAYHOUSE KITCHEN
# support: 0.011686143572621035
# confidence: 0.717948717948718
# lift: 42.08452913040069
# ==========================================================================
# rule: STRAWBERRY CHARLOTTE BAG->WOODLAND CHARLOTTE BAG
# support: 0.008712437395659432
# confidence: 0.8789473684210526
# lift: 56.15887719298245
# ==========================================================================
# rule: RED STRIPE CERAMIC DRAWER KNOB->RED SPOT CERAMIC DRAWER KNOB
# support: 0.008399415692821368
# confidence: 0.7155555555555555
# lift: 34.461730876605245
# ==========================================================================
# rule: REGENCY TEAPOT ROSES ->REGENCY MILK JUG PINK
# support: 0.010068864774624374
# confidence: 0.7942386831275721
# lift: 36.68425801973326
# ==========================================================================
# rule: REGENCY TEAPOT ROSES ->REGENCY SUGAR BOWL GREEN
# support: 0.008034223706176962
# confidence: 0.8324324324324326
# lift: 38.448349071963534
# ==========================================================================
# rule: REGENCY TEA PLATE PINK->REGENCY TEA PLATE GREEN
# support: 0.013303422370617697
# confidence: 0.9172661870503598
# lift: 39.51046803007033
# ==========================================================================
# rule: REGENCY TEA PLATE PINK->ROSES REGENCY TEACUP AND SAUCER
# support: 0.009234140233722871
# confidence: 0.7763157894736842
# lift: 48.788265746333046
# ==========================================================================
# rule: ROSES REGENCY TEACUP AND SAUCER ->REGENCY TEA PLATE GREEN
# support: 0.010799248747913189
# confidence: 0.9078947368421053
# lift: 39.106800709639266
# ==========================================================================
# rule: REGENCY TEA PLATE PINK->ROSES REGENCY TEACUP AND SAUCER
# support: 0.009390651085141904
# confidence: 0.9326424870466322
# lift: 40.172789194853586
# ==========================================================================
# rule: SET OF 3 WOODEN HEART DECORATIONS->SET OF 3 WOODEN TREE DECORATIONS
# support: 0.009025459098497496
# confidence: 0.8009259259259259
# lift: 52.57584982242516
# ==========================================================================
# rule: SET OF 3 WOODEN STOCKING DECORATION->SET OF 3 WOODEN SLEIGH DECORATIONS
# support: 0.008242904841402337
# confidence: 0.7821782178217822
# lift: 51.345178353451786
# ==========================================================================
# rule: ALARM CLOCK BAKELIKE CHOCOLATE->ALARM CLOCK BAKELIKE GREEN
# support: 0.008034223706176962
# confidence: 0.7031963470319635
# lift: 13.753946510110897
# ==========================================================================
# rule: None->ALARM CLOCK BAKELIKE CHOCOLATE
# support: 0.011686143572621035
# confidence: 0.8115942028985508
# lift: 14.801748507287746
# ==========================================================================
# rule: ALARM CLOCK BAKELIKE CHOCOLATE->None
# support: 0.008921118530884809
# confidence: 0.7808219178082193
# lift: 14.240527612319644
# ==========================================================================
# rule: None->ALARM CLOCK BAKELIKE IVORY
# support: 0.013512103505843072
# confidence: 0.7777777777777778
# lift: 14.185008986150756
# ==========================================================================
# rule: None->ALARM CLOCK BAKELIKE GREEN
# support: 0.010851419031719533
# confidence: 0.7619047619047619
# lift: 13.895519006841555
# ==========================================================================
# rule: None->ALARM CLOCK BAKELIKE GREEN
# support: 0.0162771285475793
# confidence: 0.7482014388489209
# lift: 13.645599600243687
# ==========================================================================
# rule: None->ALARM CLOCK BAKELIKE GREEN
# support: 0.008921118530884809
# confidence: 0.7037037037037038
# lift: 12.834055749374494
# ==========================================================================
# rule: ALARM CLOCK BAKELIKE IVORY->None
# ...
# rule: PINK REGENCY TEACUP AND SAUCER->REGENCY TEAPOT ROSES
# support: 0.00813856427378965
# confidence: 0.9069767441860465
# lift: 16.32387815263675
# ==========================================================================
# rule: POPPY'S PLAYHOUSE BATHROOM->POPPY'S PLAYHOUSE KITCHEN
# support: 0.008868948247078463
# confidence: 0.8994708994708993
# lift: 39.72594055543364
# ==========================================================================
# rule: POPPY'S PLAYHOUSE LIVINGROOM ->POPPY'S PLAYHOUSE BATHROOM
# support: 0.008712437395659432
# confidence: 0.8835978835978835
# lift: 51.794508357199476
# ==========================================================================
# rule: POPPY'S PLAYHOUSE LIVINGROOM ->POPPY'S PLAYHOUSE BATHROOM
# support: 0.008712437395659432
# confidence: 0.8697916666666666
# lift: 50.98521916411824
# ==========================================================================
# rule: POPPY'S PLAYHOUSE LIVINGROOM ->POPPY'S PLAYHOUSE KITCHEN
# support: 0.011633973288814691
# confidence: 0.7170418006430868
# lift: 42.031367690295674
# ==========================================================================
# rule: STRAWBERRY CHARLOTTE BAG->WOODLAND CHARLOTTE BAG
# support: 0.008712437395659432
# confidence: 0.8789473684210526
# lift: 56.15887719298245
# ==========================================================================
# rule: RED STRIPE CERAMIC DRAWER KNOB->RED SPOT CERAMIC DRAWER KNOB
# support: 0.008399415692821368
# confidence: 0.7155555555555555
# lift: 34.461730876605245
# ==========================================================================
# rule: REGENCY TEAPOT ROSES ->REGENCY MILK JUG PINK
# support: 0.010068864774624374
# confidence: 0.7942386831275721
# lift: 36.68425801973326
# ==========================================================================
# rule: REGENCY TEAPOT ROSES ->REGENCY SUGAR BOWL GREEN
# support: 0.008034223706176962
# confidence: 0.8324324324324326
# lift: 38.448349071963534
# ==========================================================================
# rule: REGENCY TEA PLATE PINK->REGENCY TEA PLATE GREEN
# support: 0.013251252086811353
# confidence: 0.9169675090252708
# lift: 39.49760272583458
# ==========================================================================
# rule: REGENCY TEA PLATE PINK->ROSES REGENCY TEACUP AND SAUCER
# support: 0.009181969949916527
# confidence: 0.775330396475771
# lift: 48.7263378349101
# ==========================================================================
# rule: ROSES REGENCY TEACUP AND SAUCER ->REGENCY TEA PLATE GREEN
# support: 0.010747078464106845
# confidence: 0.907488986784141
# lift: 39.08932336781666
# ==========================================================================
# rule: REGENCY TEA PLATE PINK->ROSES REGENCY TEACUP AND SAUCER
# support: 0.00933848080133556
# confidence: 0.9322916666666667
# lift: 40.15767790262172
# ==========================================================================
# rule: SET OF 3 WOODEN HEART DECORATIONS->SET OF 3 WOODEN STOCKING DECORATION
# support: 0.008973288814691152
# confidence: 0.8
# lift: 52.515068493150686
# ==========================================================================
# rule: SET OF 3 WOODEN STOCKING DECORATION->SET OF 3 WOODEN SLEIGH DECORATIONS
# support: 0.008190734557595994
# confidence: 0.7810945273631841
# lift: 51.27404075512847
# ==========================================================================
# rule: PINK REGENCY TEACUP AND SAUCER->ROSES REGENCY TEACUP AND SAUCER
# support: 0.008190734557595994
# confidence: 0.9289940828402368
# lift: 16.720148901297332
# ==========================================================================
# rule: POPPY'S PLAYHOUSE LIVINGROOM ->POPPY'S PLAYHOUSE BATHROOM
# support: 0.008034223706176962
# confidence: 0.9058823529411767
# lift: 53.10077352041735
# ==========================================================================
# rule: REGENCY TEA PLATE PINK->ROSES REGENCY TEACUP AND SAUCER
# support: 0.00881677796327212
# confidence: 0.9548022598870056
# lift: 41.127302735986795
# ==========================================================================
# rule: ROSES REGENCY TEACUP AND SAUCER ->None
# support: 0.01335559265442404
# confidence: 0.8648648648648648
# lift: 15.565943408196928
# ==========================================================================
# rule: REGENCY TEA PLATE ROSES ->None
# support: 0.008190734557595994
# confidence: 0.8579234972677596
# lift: 36.95433167556947
# ==========================================================================
# rule: ROSES REGENCY TEACUP AND SAUCER ->None
# support: 0.008608096828046745
# confidence: 0.9016393442622951
# lift: 16.227814977295466
# ==========================================================================
# rule: REGENCY TEA PLATE ROSES ->ROSES REGENCY TEACUP AND SAUCER
# support: 0.008555926544240401
# confidence: 0.9479768786127167
# lift: 17.061803576759207
# ==========================================================================
# rule: REGENCY TEA PLATE PINK->REGENCY TEA PLATE ROSES
# support: 0.008347245409015025
# confidence: 0.9195402298850575
# lift: 39.6084205088467
# ==========================================================================
# rule: REGENCY TEA PLATE PINK->ROSES REGENCY TEACUP AND SAUCER
# support: 0.008034223706176962
# confidence: 0.8850574712643678
# lift: 15.929372403000379
# ==========================================================================
# rule: REGENCY TEA PLATE ROSES ->ROSES REGENCY TEACUP AND SAUCER
# support: 0.009442821368948248
# confidence: 0.905
# lift: 16.28830046948357
# ==========================================================================
# rule: JUMBO SHOPPER VINTAGE RED PAISLEY->JUMBO BAG PINK POLKADOT
# support: 0.008868948247078463
# confidence: 0.7423580786026199
# lift: 23.212919495358925
# ==========================================================================
# rule: JUMBO BAG PINK POLKADOT->JUMBO BAG RED RETROSPOT
# support: 0.009181969949916527
# confidence: 0.7685589519650654
# lift: 23.272887821905805
# ==========================================================================
# rule: JUMBO SHOPPER VINTAGE RED PAISLEY->JUMBO BAG PINK POLKADOT
# support: 0.009547161936560935
# confidence: 0.7754237288135594
# lift: 23.48076150694835
# ==========================================================================
# rule: JUMBO SHOPPER VINTAGE RED PAISLEY->JUMBO BAG PINK POLKADOT
# support: 0.008242904841402337
# confidence: 0.8061224489795917
# lift: 24.410355611438884
# ==========================================================================
# rule: JUMBO SHOPPER VINTAGE RED PAISLEY->JUMBO BAG RED RETROSPOT
# support: 0.009234140233722871
# confidence: 0.7629310344827586
# lift: 23.102467723484228
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->LUNCH BAG APPLE DESIGN
# support: 0.008295075125208681
# confidence: 0.7162162162162161
# lift: 8.839943613929448
# ==========================================================================
# rule: LUNCH BAG APPLE DESIGN->LUNCH BAG SUKI DESIGN
# support: 0.008712437395659432
# confidence: 0.7522522522522522
# lift: 13.30181842358964
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->LUNCH BAG APPLE DESIGN
# support: 0.008295075125208681
# confidence: 0.7794117647058822
# lift: 9.619938638687927
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->LUNCH BAG APPLE DESIGN
# support: 0.008712437395659432
# confidence: 0.7198275862068966
# lift: 8.884517174767414
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->LUNCH BAG APPLE DESIGN
# support: 0.009808013355592655
# confidence: 0.704119850187266
# lift: 8.690643456786551
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->LUNCH BAG APPLE DESIGN
# support: 0.00813856427378965
# confidence: 0.7289719626168224
# lift: 8.997382214706537
# ==========================================================================
# rule: LUNCH BAG APPLE DESIGN->LUNCH BAG SPACEBOY DESIGN
# support: 0.008868948247078463
# confidence: 0.7327586206896551
# lift: 12.957119226364677
# ==========================================================================
# rule: LUNCH BAG APPLE DESIGN->LUNCH BAG WOODLAND
# support: 0.008242904841402337
# confidence: 0.7383177570093458
# lift: 13.055419526157877
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->LUNCH BAG PINK POLKADOT
# support: 0.011686143572621035
# confidence: 0.736842105263158
# lift: 9.09451994441997
# ==========================================================================
# rule: LUNCH BAG SUKI DESIGN ->LUNCH BAG PINK POLKADOT
# support: 0.00933848080133556
# confidence: 0.7489539748953975
# lift: 11.330662818307008
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->LUNCH BAG SUKI DESIGN
# support: 0.010747078464106845
# confidence: 0.7279151943462898
# lift: 8.984338985981767
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->LUNCH BAG WOODLAND
# support: 0.009390651085141904
# confidence: 0.7228915662650602
# lift: 8.922334540997216
# ==========================================================================
# rule: LUNCH BAG WOODLAND->LUNCH BAG SPACEBOY DESIGN
# support: 0.009129799666110184
# confidence: 0.7028112449799196
# lift: 11.643462354170353
# ==========================================================================
# rule: LUNCH BAG WOODLAND->LUNCH BAG SUKI DESIGN
# support: 0.008347245409015025
# confidence: 0.7079646017699115
# lift: 10.710548924013942
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->LUNCH BAG SPACEBOY DESIGN
# support: 0.01027754590984975
# confidence: 0.7490494296577946
# lift: 9.245189612157507
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->LUNCH BAG PINK POLKADOT
# support: 0.010642737896494158
# confidence: 0.7756653992395437
# lift: 9.573698887716404
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->LUNCH BAG WOODLAND
# support: 0.009599332220367279
# confidence: 0.7666666666666666
# lift: 9.462631465979824
# ==========================================================================
# rule: LUNCH BAG SPACEBOY DESIGN ->LUNCH BAG PINK POLKADOT
# support: 0.008295075125208681
# confidence: 0.7644230769230769
# lift: 11.564689454192216
# ==========================================================================
# rule: LUNCH BAG WOODLAND->LUNCH BAG SPACEBOY DESIGN
# support: 0.008764607679465776
# confidence: 0.7
# lift: 11.596888504753672
# ==========================================================================
# rule: LUNCH BAG WOODLAND->LUNCH BAG PINK POLKADOT
# support: 0.008190734557595994
# confidence: 0.7405660377358492
# lift: 11.203764649819066
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->LUNCH BAG WOODLAND
# support: 0.010068864774624374
# confidence: 0.7423076923076923
# lift: 9.161979295656051
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->LUNCH BAG WOODLAND
# support: 0.009599332220367279
# confidence: 0.757201646090535
# lift: 9.345808855288716
# ==========================================================================
# rule: LUNCH BAG WOODLAND->LUNCH BAG SPACEBOY DESIGN
# support: 0.008295075125208681
# confidence: 0.7194570135746605
# lift: 10.884413603945614
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->LUNCH BAG APPLE DESIGN
# support: 0.009025459098497496
# confidence: 0.762114537444934
# lift: 13.476209828177577
# ==========================================================================
# rule: LUNCH BAG APPLE DESIGN->LUNCH BAG SPACEBOY DESIGN
# support: 0.008190734557595994
# confidence: 0.7621359223300971
# lift: 13.476587969763193
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->LUNCH BAG APPLE DESIGN
# support: 0.008399415692821368
# confidence: 0.7815533980582523
# lift: 9.646371882794964
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->LUNCH BAG APPLE DESIGN
# support: 0.008973288814691152
# confidence: 0.7196652719665272
# lift: 8.882513801065288
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->LUNCH BAG APPLE DESIGN
# support: 0.008086393989983306
# confidence: 0.7209302325581396
# lift: 8.898126656583658
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->LUNCH BAG APPLE DESIGN
# support: 0.008451585976627712
# confidence: 0.7570093457943924
# lift: 9.343435376810634
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->LUNCH BAG SPACEBOY DESIGN
# support: 0.009964524207011686
# confidence: 0.731800766283525
# lift: 9.032296901559953
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->LUNCH BAG SUKI DESIGN
# support: 0.00975584307178631
# confidence: 0.7824267782426777
# lift: 9.65715163255354
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->LUNCH BAG WOODLAND
# support: 0.009442821368948248
# confidence: 0.7801724137931034
# lift: 9.629326997801808
# ==========================================================================
# rule: LUNCH BAG WOODLAND->LUNCH BAG SPACEBOY DESIGN
# support: 0.008555926544240401
# confidence: 0.706896551724138
# lift: 11.71114356391381
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->LUNCH BAG SPACEBOY DESIGN
# support: 0.009547161936560935
# confidence: 0.7011494252873564
# lift: 8.653980800971054
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->LUNCH BAG WOODLAND
# support: 0.00975584307178631
# confidence: 0.722007722007722
# lift: 8.911425637761761
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->LUNCH BAG WOODLAND
# support: 0.008973288814691152
# confidence: 0.7610619469026549
# lift: 9.393454860418602
# ==========================================================================
# rule: LUNCH BAG WOODLAND->LUNCH BAG SPACEBOY DESIGN
# support: 0.008086393989983306
# confidence: 0.7013574660633485
# lift: 11.730907425394646
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->LUNCH BAG SPACEBOY DESIGN
# support: 0.008399415692821368
# confidence: 0.7740384615384615
# lift: 9.55361830699886
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->LUNCH BAG WOODLAND
# support: 0.009860183639398999
# confidence: 0.7974683544303799
# lift: 9.84280323098617
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->LUNCH BAG WOODLAND
# support: 0.009181969949916527
# confidence: 0.8301886792452831
# lift: 10.246655894252148
# ==========================================================================
# rule: LUNCH BAG RED RETROSPOT->LUNCH BAG WOODLAND
# support: 0.008764607679465776
# confidence: 0.7601809954751131
# lift: 9.382581662116529
# ==========================================================================
# rule: REGENCY TEA PLATE ROSES ->ROSES REGENCY TEACUP AND SAUCER
# support: 0.00813856427378965
# confidence: 0.9285714285714286
# lift: 16.71254191817572
# ==========================================================================
# rule: POPPY'S PLAYHOUSE KITCHEN->POPPY'S PLAYHOUSE BEDROOM
# support: 0.008034223706176962
# confidence: 0.9058823529411767
# lift: 53.10077352041735
# ==========================================================================
# rule: REGENCY TEA PLATE PINK->REGENCY TEA PLATE ROSES
# support: 0.008764607679465776
# confidence: 0.9545454545454546
# lift: 41.116241062308475
# ==========================================================================
