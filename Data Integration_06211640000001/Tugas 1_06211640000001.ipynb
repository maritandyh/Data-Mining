# %% [markdown]
# # Tugas 1
# ## Data Integration

# %%
import pandas as pd

# %%
#Data Big Mart Sales
bmd1 = pd.read_csv("E:\Big Mart Data 1.csv")
bmd2 = pd.read_csv("E:\Big Mart Data 2.csv")

bmd_complete = pd.merge(bmd1, bmd2, on = 'Item Identifier')
bmd_complete.head(20)
# Out:
#    Item Identifier Item Fat Content Item Type Outlet Identifier Outlet Size  \
# 0            FDA15          Low Fat     Dairy            OUT049      Medium
# 1            FDA15          Low Fat     Dairy            OUT049      Medium
# 2            FDA15          Low Fat     Dairy            OUT049      Medium
# 3            FDA15          Low Fat     Dairy            OUT049      Medium
# 4            FDA15          Low Fat     Dairy            OUT049      Medium
# 5            FDA15          Low Fat     Dairy            OUT049      Medium
# 6            FDA15          Low Fat     Dairy            OUT049      Medium
# 7            FDA15          Low Fat     Dairy            OUT049      Medium
# 8            FDA15          Low Fat     Dairy            OUT045           -
# 9            FDA15          Low Fat     Dairy            OUT045           -
# 10           FDA15          Low Fat     Dairy            OUT045           -
# ...

# %%
#Data Big Mart Sales
bmd1 = pd.read_csv("E:\Big Mart Data 1.csv")
bmd2 = pd.read_csv("E:\Big Mart Data 22.csv")

bmd_complete2 = pd.merge(bmd1, bmd2, on = 'Item Type')
bmd_complete2.head(20)
# Out:
#    Item Identifier Item Fat Content Item Type Outlet Identifier Outlet Size  \
# 0            FDA15          Low Fat     Dairy            OUT049      Medium
# 1            FDA15          Low Fat     Dairy            OUT049      Medium
# 2            FDA15          Low Fat     Dairy            OUT049      Medium
# 3            FDA15          Low Fat     Dairy            OUT049      Medium
# 4            FDA15          Low Fat     Dairy            OUT049      Medium
# 5            FDA15          Low Fat     Dairy            OUT049      Medium
# 6            FDA15          Low Fat     Dairy            OUT049      Medium
# 7            FDA15          Low Fat     Dairy            OUT049      Medium
# 8            FDA15          Low Fat     Dairy            OUT049      Medium
# 9            FDA15          Low Fat     Dairy            OUT049      Medium
# 10           FDA15          Low Fat     Dairy            OUT049      Medium
# ...

# %%
#Data Big Mart Sales
bmd1 = pd.read_csv("E:\Big Mart Data 1.csv")
bmd2 = pd.read_csv("E:\Big Mart Data 22.csv")

bmd_complete3 = pd.merge(bmd1, bmd2, on = 'Item Type')
bmd_complete3[1200:1210]
# Out:
#      Item Identifier Item Fat Content Item Type Outlet Identifier Outlet Size  \
# 1200           FDA03          Regular     Dairy            OUT046       Small
# 1201           FDA03          Regular     Dairy            OUT046       Small
# 1202           FDA03          Regular     Dairy            OUT046       Small
# 1203           FDA03          Regular     Dairy            OUT046       Small
# 1204           FDA03          Regular     Dairy            OUT046       Small
# 1205           FDA03          Regular     Dairy            OUT046       Small
# 1206           FDA03          Regular     Dairy            OUT046       Small
# 1207           FDA03          Regular     Dairy            OUT046       Small
# 1208           FDA03          Regular     Dairy            OUT046       Small
# 1209           FDA03          Regular     Dairy            OUT046       Small
#
#      Outlet Location Type        Outlet Type  Outlet Establishment Year  \
# ...

# %%
#Data Big Mart Sales
bmd1 = pd.read_csv("E:\Grocery Store.csv")
bmd2 = pd.read_csv("E:\Supermarket Type1.csv")
bmd3 = pd.read_csv("E:\Supermarket Type2.csv")
bmd4 = pd.read_csv("E:\Supermarket Type3.csv")

bmd_complete4 = pd.concat([bmd1, bmd2, bmd3, bmd4])
bmd_complete4
# Out:
#     Item Identifier Item Fat Content              Item Type Outlet Identifier  \
# 0             FDX07          Regular  Fruits and Vegetables            OUT010
# 1             FDC37          Low Fat           Baking Goods            OUT019
# 2             FDE51          Regular                  Dairy            OUT010
# 3             FDC14          Regular                 Canned            OUT019
# 4             FDV38          Low Fat                  Dairy            OUT010
# 5             FDM39               LF                  Dairy            OUT010
# 6             FDS02          Regular                  Dairy            OUT019
# 7             FDI26          Low Fat                 Canned            OUT019
# 8             FDY40          Regular           Frozen Foods            OUT019
# 9             FDC46               LF            Snack Foods            OUT010
# 10            FDN48          Low Fat           Baking Goods            OUT019
# ...

# %%
## Variabel yang digunakan
Variable = {'Item Identifier':'Unique product ID', 
            'Item Weight':'Weight of product', 
            'Item Fat Content':'Whether the product is low fat or not', 
            'Item Visibility':'The % of total display area of all products in a store allocated to the particular product', 
            'Item Type':'The category to which the product belongs', 
            'Item MRP':'Maximum Retail Price (list price) of the product',
            'Outlet Identifier':'Unique store ID', 
            'Outlet Establishment Year':'The year in which store was established', 
            'Outlet Size':'The size of the store in terms of ground area covered', 
            'Outlet Location Type':'The type of city in which the store is located', 
            'Outlet Type':'Whether the outlet is just a grocery store or some sort of supermarket', 
            'Item Outlet Sales':'Sales of the product in the particulat store. This is the outcome variable to be predicted'}

# %%
Variable['Item Identifier']
# Out:
# 'Unique product ID'

# %% [markdown]
# ### Sumber Data : https://www.kaggle.com/jainshreya1997/a102-big-mart-sales-day-1/data
